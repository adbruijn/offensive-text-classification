# %%
### Import packages ###
#Basics
import numpy as np
import pandas as pd
import nltk
from nltk.corpus import stopwords
import re
from collections import Counter
import string

#Visualization
import seaborn as sns
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
# %matplotlib inline
from plotnine import *

from IPython.display import display, HTML
import pandas_profiling

#NLP
from nltk.tokenize import TweetTokenizer
from keras.preprocessing.text import Tokenizer

import contractions
from wordsegment import load, segment
#https://pypi.org/project/wordsegment/
#https://github.com/cbaziotis/ekphrasis
#word segmentation, spell correction????

from spellchecker import SpellChecker

#Emojis & emoticons
import emojis
#https://pypi.org/project/emojis/

import emot
#https://pypi.org/project/emot/
# Out:
# Using TensorFlow backend.

# %%
### Import data ###
train = pd.read_csv('./data/SemEval/olid-training-v1.0.tsv', sep='\t')
test_a = pd.read_csv('./data/SemEval/testset-levela.tsv', sep='\t')
test_b = pd.read_csv('./data/SemEval/testset-levelb.tsv', sep='\t')
test_c = pd.read_csv('./data/SemEval/testset-levelc.tsv', sep='\t')

train.head(1)
labels_a = pd.read_csv('./data/SemEval/labels-levela.csv', header=None)
labels_a.columns = ['id', 'subtask_a']
test_a = pd.merge(test_a, labels_a, on='id')

labels_b = pd.read_csv('./data/SemEval/labels-levelb.csv', header=None)
labels_b.columns = ['id', 'subtask_b']
test_b = pd.merge(test_b, labels_b, on='id')

labels_c = pd.read_csv('./data/SemEval/labels-levelc.csv', header=None)
labels_c.columns = ['id', 'subtask_c']
test_c = pd.merge(test_c, labels_c, on='id')

# %%
pandas_profiling.ProfileReport(train)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>5 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>13240 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>27.5% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>517.3 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>40.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>4 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_subtask_b"><code>subtask_b</code></a> has 8840 / 66.8% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_subtask_c"><code>subtask_c</code></a> has 9364 / 70.7% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_tweet"><code>tweet</code></a> has a high cardinality: 13207 distinct values  <span class="label label-warning">Warning</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_id">id<br/>
#             <small>Numeric</small>
#         </p>
#     </div><div class="col-md-6">
#     <div class="row">
#         <div class="col-sm-6">
#             <table class="stats ">
#                 <tr>
#                     <th>Distinct count</th>
#                     <td>13240</td>
#                 </tr>
#                 <tr>
#                     <th>Unique (%)</th>
#                     <td>100.0%</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Missing (%)</th>
#                     <td>0.0%</td>
#                 </tr>
#                 <tr

# %%
display(train.tail(3))
display(test_a.head(3))
display(test_b.head(3))
display(test_c.head(3))
# Out:
#           id                                              tweet subtask_a  \
# 13237  82921  @USER And why report this garbage.  We don't g...       OFF
# 13238  27429                                        @USER Pussy       OFF
# 13239  46552  #Spanishrevenge vs. #justice #HumanRights and ...       NOT
#
#       subtask_b subtask_c
# 13237       TIN       OTH
# 13238       UNT       NaN
# 13239       NaN       NaN
#       id                                              tweet subtask_a
# 0  15923  #WhoIsQ #WheresTheServer #DumpNike #DECLASFISA...       OFF
# 1  27014  #ConstitutionDay is revered by Conservatives, ...       NOT
# 2  30530  #FOXNews #NRA #MAGA #POTUS #TRUMP #2ndAmendmen...       NOT
#       id                                              tweet subtask_b
# 0  15923  #WhoIsQ #WheresTheServer #DumpNike #DECLASFISA...       TIN
# 1  60133  #NoPasaran: Unity demo to oppose the far-right...       TIN
# 2  83681           . . . What the fuck did he do this time?       TIN
#       id                                              tweet subtask_c
# 0  15923  #WhoIsQ #WheresTheServer #DumpNike #DECLASFISA...       OTH
# 1  60133  #NoPasaran: Unity demo to oppose the far-right...       GRP
# 2  83681           . . . What the fuck did he do this time?       IND

# %% [markdown]
# ### Examples

# %%
#NOT
display(pd.DataFrame(train[train.subtask_a=="NOT"].loc[:,'tweet'].sample(n=3)))
print("NOT")

#OFF & TIN & GRP
display(pd.DataFrame(train.loc[(train["subtask_a"]=="OFF")&(train["subtask_b"]=="TIN")&(train["subtask_c"]=="GRP"),"tweet"].sample(n=3)))
print("OFF & TIN & GRP")

#OFF & TIN & IND
display(pd.DataFrame(train.loc[(train["subtask_a"]=="OFF")&(train["subtask_b"]=="TIN")&(train["subtask_c"]=="IND"),"tweet"].sample(n=3)))
print("OFF & TIN & IND")

#OFF & TIN & OTH
display(pd.DataFrame(train.loc[(train["subtask_a"]=="OFF")&(train["subtask_b"]=="TIN")&(train["subtask_c"]=="OTH"),"tweet"].sample(n=3)))
print("OFF & TIN & OTH")

#OFF & UNT
display(pd.DataFrame(train.loc[(train["subtask_a"]=="OFF")&(train["subtask_b"]=="UNT"),"tweet"].sample(n=3)))
print("OFF & UNT")
# Out:
#                                                   tweet
# 7988  @USER @USER why don't the likes of just do as ...
# 5183  @USER what about this woman  .funny I dont see...
# 7221  10)  But why?  Do they hate us that much?"    ...
# NOT
#                                                    tweet
# 12672  @USER Fudge report...then apparently she is no...
# 12831  @USER @USER @USER @USER @USER Amazing how they...
# 11674  @USER Embarrassing for the liberals....I wonde...
# OFF & TIN & GRP
#                                                   tweet
# 8532                     @USER @USER Bitch I wanna know
# 7766  @USER @USER Dubious mortgages? lol You mean th...
# 7907  @USER @USER trump may not be the one who start...
# OFF & TIN & IND
#                                                    tweet
# 12192  @USER You will not win. Texas doesn’t need a l...
# 3108   @USER Holder has a perverted view of the law. ...
# 671    Was this a threat from @USER #DangerousDemocra...
# OFF & TIN & OTH
#                                                    tweet
# 5477                 @USER Exactly... they're all bitter
# 11267  @USER Twitter is becoming tumblr 2013 and I am...
# 6188   @USER @USER @USER @USER So if Paul Golding tur...
# OFF & UNT

# %%
print("Shape training: {}".format(train.shape))
print("Shape test A: {}".format(test_a.shape))
print("Shape test B: {}".format(test_b.shape))
print("Shape test C: {}".format(test_c.shape))
# Out:
# Shape training: (13240, 5)
# Shape test A: (860, 3)
# Shape test B: (240, 3)
# Shape test C: (213, 3)

# %% [markdown]
# ### Tokens

# %%
tokenizer_train = Tokenizer(lower=True)
tokenizer_train.fit_on_texts(train['tweet'])
vocab_train = len(tokenizer_train.word_index) + 1
print("Vocab size train:", vocab_train)

tokenizer_test = Tokenizer(lower=True)
tokenizer_test.fit_on_texts(test_a['tweet'])
vocab_test = len(tokenizer_test.word_index) + 1
print("Vocab size train:", vocab_test)

set_train = set(list(tokenizer_train.word_index.keys()))
set_test = set(list(tokenizer_test.word_index.keys()))

set_train-set_test
# Out:
# Vocab size train: 21244
# Vocab size train: 5480
# {'repro',
#  'yayay',
#  'huh😏',
#  'africa',
#  'ferries',
#  '\U0001f92a',
#  'deletion',
#  'rebekahismoftheday',
#  'psychic',
#  'troubleshooting',
#  'alternative',
#  'ronald',
#  '😝',
#  'dnt',
#  "90's",
#  'funner',
#  'nraun',
#  'billy',
#  'henderson',
#  'multicultural',
#  'prettiest',
#  '🚑',
#  'decommissioned',
#  'impeccable',
#  'saudis',
#  'novel',
#  'realtor',
#  'splitting',
#  'iraqi',
#  'telly',
#  '55yr',
#  'sanctity',
#  'extremistische',
#  'shitty',
#  'papers',
#  'mbappe',
#  'youre',
#  'toolbox',
#  'cave',
#  'ig',
#  'visually',
#  'rabbit',
#  'barrel',
#  'tristan',
#  '“get”',
#  'gates',
#  'benny',
#  'hilariously',
#  'radicalized',
#  'unethical',
#  'portraying',
#  'buryblue',
#  'indicating',
#  'beliw👍👍united',
#  'psuedo',
#  'corrruption',
#  'reorganize',
#  'witchhunt',
#  'children💞why',
#  'pictures',
#  '81st',
#  'lawsuit',
#  'fm19',
#  'mythicalcreature',
#  'commercials',
#  'dez',
#  'referred',
#  'outlier',
#  'neveragain',
#  'rga',
#  'lackeys',
#  'ripe',
#  'ainge',
#  'assumptions',
#  'cheeseburger',
#  'menopausal',
#  "gov't",
#  'communicate',
#  'clear',
#  'positive',
#  'disconnected',
#  'admired',
#  'supervision',
#  'protocols',
#  'guarding',
#  'missouri',
#  'cooktragic',
#  'pig',
#  'walls',
#  'bin',
#  'sads',
#  'fashions',
#  'subscribers',
#  'amongst',
#  "o'keefe",
#  'howard',
#  'annually',
#  '52',
#  'kathryn',
#  '‘from',
#  'biter',
#  'cheney',
#  'half',
#  'connelly',
#  "amputees'",
#  'toxic',
#  'dots',
#  'convicts',
#  'lengths',
#  'mensch',
#  'mad',
#  'lady🙂',
#  'shared',
#  'horrid',
#  'preseason',
#  'winnig',
#  'hosting',
#  'roy',
#  'exams',
#  'shon’s',
#  'weaponised',
#  'bullying',
#  'worshippers',
#  'hesanidiot',
#  'improved',
#  'gangsta',
#  'rezz',
#  'trumpwall',
#  'relativizing',
#  'sport',
#  'imagery',
#  'establishing',
#  'repug',
#  'lbj',
#  'size',
#  'heh',
#  'aries',
#  'stolen',
#  'panel',
#  'sections',
#  'partybeforecountry',
#  '😁😁',
#  'slot”',
#  'exec',
#  'db',
#  'deary',
#  'acknowledges',
#  'kampf',
#  'skies',
#  'privitizing',
#  'extrapolate',
#  'queens',
#  'salaries',
#  'aura',
#  'divide',
#  'folding',
#  'jealousy',
#  'ssi',
#  'baz',
#  'paint',
#  'flirting',
#  'mk',
#  'juan',
#  'cabinet',
#  'amazingly',
#  'lightweight',
#  'deliberate',
#  '40s',
#  'jr',
#  'rss',
#  'kool',
#  'outdone',
#  'defends',
#  'isle',
#  'epitomizes',
#  'humour',
#  'forging',
#  'organiser',
#  'requisite',
#  'bluelivesmatter',
#  'dickbrain',
#  'usko',
#  "everyone's",
#  'doggie',
#  'inauguration',
#  'dat',
#  'map',
#  'extrajudicial',
#  'ala',
#  'convey',
#  'butt💀',
#  'deirdre',
#  'kaise',
#  'kermit',
#  'uighur',
#  'trumpnation',
#  'sponsor',
#  'borrower',
#  'srsly',
#  'philippines',
#  'birch',
#  'jail',
#  'kendall',
#  'chunk',
#  'greasy',
#  'mix',
#  'suspicious',
#  'ehave',
#  'bhakt',
#  'lions',
#  '🤔🤔',
#  'outoftheeu',
#  'moved',
#  'evolving',
#  'carlos',
#  'monologues',
#  'suit😂😂',
#  'faerie',
#  'disrespectful',
#  'migration',
#  'memorable',
#  'diss',
#  'prosecuting',
#  'hiya',
#  'messed',
#  'deemed',
#  "says'",
#  'herrera',
#  'better😭',
#  'twitter”conversations”but',
#  'nationalised',
#  'schumer’s',
#  'regime',
#  'picturing',
#  'dion',
#  'cus',
#  'egghead',
#  'lit',
#  'thin',
#  'ain',
#  'lining',
#  'nerd',
#  'opportunist',
#  'lisapage',
#  'mcfartney',
#  'booter',
#  'disasters',
#  'groups’',
#  'compliance',
#  'fussing',
#  'ultra',
#  'merck',
#  'bout',
#  'gestapo',
#  'ecstatic',
#  'colleen',
#  'umm',
#  '38',
#  'marginalizing',
#  'doctrine',
#  'competence',
#  'reprisal',
#  'speculate',
#  '\U0001f6f8',
#  'betting',
#  'bashing',
#  'aca',
#  'overtime',
#  'makeamericagreatagain',
#  'assaulted',
#  'skepticism',
#  'admin',
#  'xrpcommunity',
#  'starfire',
#  'satisfies',
#  'additional',
#  'methodical',
#  'hangin',
#  'bravos',
#  'eights',
#  'holster',
#  'posting',
#  'pawn',
#  'messaged',
#  'demonizes',
#  'studied',
#  '🙏🏼🙏🏼🙏🏼🙏🏼',
#  'bhajpaa',
#  '“wrong”',
#  'civilised',
#  'campers',
#  'regrettable',
#  'konk',
#  'yessir',
#  'pilled',
#  'rival',
#  'cdns',
#  'disappointing',
#  'evilness',
#  'kahlili',
#  'theyll',
#  'defamation',
#  'helpful',
#  'leopard',
#  'demswanttotalcontrol',
#  'neck',
#  'graham',
#  'revoke',
#  'lineswoman',
#  'gullibles',
#  'streams',
#  'twists',
#  '05',
#  'waffen',
#  'tana',
#  'pc',
#  'authority',
#  'passive',
#  'reportedly',
#  'accuracy',
#  'disproven',
#  'ko',
#  'determined',
#  'factsmatter',
#  'excommunicate',
#  'timed',
#  'offender',
#  'blender',
#  'too👍👍👍👍',
#  'axis',
#  'ernieandbert',
#  '😒😠😠😠',
#  'cure',
#  'etiquette',
#  'cj',
#  'corrections',
#  'mos2',
#  '🍿',
#  'filter',
#  'separation',
#  'rider',
#  'jacobite',
#  'eirc',
#  '£33bn',
#  'lead',
#  'royce',
#  'obscenities',
#  'deal’',
#  'roid',
#  'destroysovereignusa',
#  'bow',
#  'antinatalist',
#  'jim',
#  'boards',
#  'champion',
#  'condensed',
#  'beefing',
#  'servers',
#  'huffing',
#  'shev',
#  'disappointment',
#  '208',
#  'hook',
#  'cobra',
#  'disturbed',
#  'narrow',
#  'couch',
#  'equivalency',
#  'bringbridgetback',
#  '🚂',
#  'prelude',
#  'fuxnews',
#  'weirdos',
#  'complacency',
#  'dubakoor',
#  'misinterpret',
#  'notrust',
#  'becoz',
#  'reliever',
#  'taketworeferenceswithmoniqueandchloe',
#  'xilhatarra',
#  'strait',
#  'inhales',
#  'variety',
#  'subsidised',
#  'barun',
#  'bio😂',
#  'icecream',
#  'meaningless',
#  'polytechno',
#  'asphalt',
#  'softly',
#  '\U0001f9df\u200d♂️',
#  '👍👍',
#  'underoath',
#  '😩😍',
#  '🤗',
#  'cuba',
#  'categorizes',
#  'nowheresland',
#  'connecting',
#  'high”',
#  'shiny',
#  'nymphet',
#  'creepyjoebiden',
#  'freeze',
#  'pounded',
#  'disco',
#  'avi',
#  'cosy',
#  'scalise',
#  'niggaz',
#  'vibe',
#  'playoffs',
#  'rug',
#  '“christian',
#  'weenie',
#  'foriegn',
#  'conclude',
#  'cube',
#  'assurances',
#  'stomped',
#  'dismembered',
#  'corporates',
#  'screened',
#  'buildthatwall',
#  '£1',
#  '‘controlled’',
#  'smg',
#  'transphobic',
#  'rank',
#  'obama’s',
#  '🎶🇺🇸',
#  'throwing',
#  'fabricates',
#  'slouches',
#  'disagreed',
#  'tonight😂',
#  'dolt',
#  'ihmykgodoosj',
#  'joyful',
#  'fundamental',
#  'babysitting',
#  'abhorrent',
#  'shuting',
#  'parasitic',
#  'publicizing',
#  'pentagon',
#  'apartaments',
#  'i’m100',
#  'postal',
#  'vg',
#  'ligic',
#  'toolate😎',
#  'links',
#  '‘probably',
#  'wisely',
#  'ong',
#  'domo',
#  '🇮🇹',
#  'handshake',
#  'insurance',
#  'messiness',
#  'militant',
#  'clingvto',
#  'wave”',
#  'cart',
#  'visibly',
#  'deter',
#  'appease',
#  'albertpike1871',
#  "'hourglass'",
#  'instruct',
#  '‘analyzing',
#  'liberalsmustgo',
#  'limp',
#  '187',
#  'bites',
#  'toad',
#  'ost',
#  '302',
#  'modest',
#  'jurist',
#  'amends',
#  'catfight',
#  'subpoenas',
#  'corruptions',
#  'biblical',
#  'lmfaoo',
#  'dealers',
#  'goldwater',
#  'kraber',
#  '‘divide',
#  'commerce',
#  'plagued',
#  'envy',
#  'ramsgate',
#  'physically',
#  'posing',
#  'rolling',
#  'weirdly',
#  'theconcerttour',
#  'subverting',
#  'validity',
#  'wider',
#  'duet',
#  'mo',
#  'reunion',
#  'poly',
#  'substance',
#  'tripletalaq',
#  'foremost',
#  'mentions',
#  'konjam',
#  'glare',
#  'affects',
#  '👇please',
#  'locally',
#  'outcome',
#  "shouldn't",
#  'mariota',
#  '👂',
#  'regulation',
#  'bigtech',
#  'liberaltarian',
#  'smb',
#  'pinstriped',
#  '105',
#  'reminds',
#  'wheeew',
#  'h3ll',
#  'dush’s',
#  'misuse',
#  'mean—you’re',
#  '💁🏽\u200d♂️',
#  'fueling',
#  'punish',
#  'batsht',
#  'inbred',
#  'albert',
#  'lazy',
#  '🏘️\xa0pm',
#  'accomplish',
#  'logic',
#  'dangerously',
#  'attracted',
#  '“let',
#  'satochi',
#  'supermajority',
#  'pas',
#  'roughed',
#  'swords',
#  "'infowars'",
#  'disqualifying',
#  'dildo',
#  'shouldertoshoulder',
#  'farmer',
#  'percentile',
#  'uncivil',
#  'sandyhook',
#  'rocket',
#  'repercussions',
#  "usconstndem'y",
#  'illustration',
#  'person\U0001f92e\U0001f92e\U0001f92e\U0001f92e',
#  'hollywood’s',
#  'generic',
#  'pretend',
#  "'unprecedented'",
#  'cars',
#  'spoil',
#  'underestimate',
#  'sparking',
#  'mmz2',
#  'paths',
#  'prz',
#  'berniernation',
#  'celebrating',
#  'misdirection',
#  'she’ll',
#  'fiasco',
#  'achieve',
#  'hollowing',
#  'barn',
#  '‘has',
#  'payment',
#  'chemistry',
#  'libel',
#  'pbs',
#  'explicitly',
#  'pumpkin',
#  'cherish',
#  'mickie',
#  'towns',
#  'fixed',
#  "nobody's",
#  'kellyanne',
#  'inthe',
#  "midterms'",
#  "chris'",
#  'cues',
#  'nikki',
#  'hogwash',
#  'tit',
#  'unflattering',
#  'basing',
#  'brink',
#  'whitesupremacists',
#  'ragging',
#  'removal',
#  'gtto',
#  'beaware',
#  'yelped',
#  'squashed',
#  'sesame',
#  'tenets',
#  'ump',
#  'sins',
#  'falseprophet',
#  'copy',
#  'develop',
#  'bday',
#  'darn',
#  'vetting',
#  'visited',
#  'assist',
#  '💩😂',
#  'rené',
#  'welcomeeee',
#  'redoctober',
#  'doomsday',
#  'demagogues',
#  'entertainer',
#  'grape',
#  'logo',
#  'hopefully',
#  'count',
#  'rural',
#  'leaked',
#  'elizabethholmes',
#  'histrionic',
#  'tch',
#  'possum',
#  'winnipeg',
#  'flirty',
#  'shaft',
#  'tw115',
#  'helpless',
#  'notified',
#  'kurt',
#  'command',
#  'preorder',
#  'underlying',
#  '💯🇺🇸🇺🇸🇺🇸',
#  'clouds',
#  "kkk's",
#  'rebounded',
#  'sober',
#  'tribalism',
#  'obozo',
#  'hasty',
#  'vying',
#  'abbott',
#  'gabole',
#  'wanka',
#  'contemptuously',
#  '130',
#  'oakland',
#  'contradictions',
#  'careeeema',
#  'assumes',
#  'slavery',
#  'cu',
#  'punished',
#  '14th',
#  'ddsl',
#  'railed',
#  'unadulterated',
#  'fits',
#  'extraordinarily',
#  'dated',
#  'conner',
#  'cooper',
#  'interviews',
#  'distinguish',
#  'hazard',
#  'pog',
#  '7k',
#  'shaming',
#  'freedom—period',
#  'pmjt',
#  'boi',
#  'perpetuate',
#  'coddled',
#  'kakulitan',
#  'overlords',
#  'charge”',
#  'hahah',
#  'altar',
#  '🤷🏻\u200d♀️🤦🏻\u200d♀️',
#  'controll',
#  'loot',
#  '💗',
#  'distorts',
#  '“ruth',
#  'compose',
#  'vainly',
#  'showalter',
#  'sleeze',
#  'judiciary',
#  'demi’s',
#  'ben',
#  '357',
#  'secondammendment',
#  'kansas',
#  'hyt',
#  '😜🖕🏻✍️kma',
#  '🤣what',
#  '“comedian”',
#  'potion',
#  'limits',
#  'courthouse',
#  'knack',
#  'spoilt',
#  'jonesout',
#  'disagreeing',
#  'binged',
#  'scrawny',
#  'nicco',
#  'abbott’s',
#  "'your",
#  '🏘️',
#  'backsides',
#  '🤦🏾\u200d♂️🤦🏾\u200d♂️🤦🏾\u200d♂️🤦🏾\u200d♂️',
#  'temper',
#  'equipped',
#  'oligarchies',
#  'curb',
#  '2013',
#  'kaam',
#  'shaping',
#  'getup',
#  'difficulties',
#  'power”so',
#  'america😤🔥🙏speaker',
#  'beg',
#  'hubris',
#  '20180919',
#  'perverts',
#  'lasa',
#  'attest',
#  'selena',
#  'deficient',
#  'demonized',
#  "nation's",
#  'pruitt',
#  'cavill',
#  "d's",
#  '“dangerous',
#  'dirtbag',
#  '“brexit',
#  'solve',
#  'pharisees',
#  'wld',
#  'stream',
#  'canon',
#  'politicize',
#  'criticizes',
#  'anonymously',
#  '“no”',
#  'hooo',
#  'conclusions',
#  'cater',
#  'nomoreprogressiveliberals',
#  'firstresponder',
#  'facsicm',
#  '“family',
#  'consider',
#  'singular',
#  'sombody',
#  'frost',
#  'delayed',
#  'charms',
#  'contemporary',
#  'popcorn',
#  'diners',
#  'ocd',
#  'included',
#  'commuted',
#  'losses',
#  'recovered',
#  'hooper',
#  'bidding',
#  '‘mein',
#  'tc',
#  'deranged',
#  'overcome',
#  '☝️',
#  'scruffbag',
#  'tribes',
#  'particratic',
#  'unelected',
#  'esteem',
#  "she'd",
#  'worded',
#  'dumocrat',
#  'discussing',
#  'favored',
#  'breaths',
#  'disrespects',
#  'bureau✊🏿🌽✊🏿',
#  'gifts',
#  'chart',
#  '💙🖤',
#  'inculcate',
#  'vendetta',
#  'usarepublic',
#  'flushing',
#  'charm',
#  'oral',
#  'benign',
#  'raises',
#  'happyhappy',
#  '😂😜😘😇',
#  'cooked',
#  'separations',
#  'uber',
#  'municipal',
#  'leaf',
#  'ferengi',
#  'hello',
#  'booth',
#  'retiree',
#  'bbcan2',
#  'tow',
#  'obtaining',
#  'bullcrap',
#  'appropiated',
#  'kogasas',
#  'rake',
#  "trudeau's",
#  'nowaters',
#  'barry',
#  'bestfriend',
#  'y’all’s',
#  'hungrier',
#  'att',
#  'necessary',
#  'angel💜',
#  'dennison',
#  'fleeted',
#  'glc',
#  'eveb',
#  '😭😆🤷🏽\u200d♂️',
#  'slaves',
#  '‘how',
#  'legion”',
#  'dopest',
#  'gasses',
#  'eviction',
#  'resisttrump',
#  'kl',
#  'democraticsocialismnow',
#  'hidden',
#  'commission',
#  'miserably',
#  'cohorts',
#  'adorably',
#  'chandlermassey',
#  'asb',
#  '🤣🤣',
#  'banbury',
#  'ju',
#  'retaliate',
#  'mxm',
#  'folded',
#  'semi',
#  'invitation',
#  'blanche',
#  'afterward',
#  'day😘',
#  'skiddish',
#  'cohort',
#  'wanker',
#  'griexsevia',
#  'dandruff',
#  'hmg',
#  'wreath',
#  'pagan',
#  'golfing',
#  'tuition',
#  'demonstrates',
#  'jihadist',
#  'europeans',
#  'spend',
#  'pander',
#  'roblox',
#  'ballistic',
#  'paperback',
#  'weez',
#  'fawningly',
#  '🙏🏾peace',
#  "llc'",
#  'lotta',
#  'tmart',
#  "chills'",
#  'skeptical',
#  'duty',
#  'mcdonald',
#  'dogwhistle',
#  'admins',
#  'tie',
#  'hypnotized',
#  'notebook',
#  'victimize',
#  'triumph',
#  'rao',
#  'degrees',
#  'meps',
#  'iniated',
#  'crypts',
#  'looney',
#  'whitesupremacist',
#  'degenerates',
#  'parris',
#  'delivered',
#  'relentless',
#  'believable',
#  'misogynistic',
#  'registrar',
#  'blanket',
#  'toryparty',
#  '15th',
#  'returning',
#  'straightening',
#  'alcatraz',
#  'vid',
#  'sponsors',
#  'fuckbucket',
#  '😘just',
#  '43',
#  'stupidity',
#  'islamophobic',
#  'drove',
#  'cumtribute',
#  'strawberryrecall',
#  'flourishing',
#  'tamir',
#  'peterson',
#  'stood',
#  'signatures',
#  'polloftheday',
#  'capture',
#  'downloading',
#  'gonzalez',
#  'infringe',
#  'brave',
#  'admonish',
#  '23879',
#  'sponge',
#  'scrunchie',
#  'stepped',
#  'sided',
#  'life’s',
#  'bolaji',
#  '😚',
#  'ratbags',
#  'buzzwords',
#  'squirt',
#  'burden',
#  'motherfucker',
#  'scatter',
#  'landslide',
#  'primadonnas',
#  'reconnect',
#  'creates',
#  'foxreport',
#  'profile',
#  'undermining',
#  '1994',
#  'liblabcon',
#  'breast',
#  'whiney',
#  'mehn',
#  'jamie',
#  'gophypocrites',
#  'clash',
#  'sos',
#  'element',
#  'toosoon',
#  'justly',
#  'signals',
#  'relativists',
#  'celebrity😂😂😂',
#  '🐷',
#  'declassifypowsdocuments',
#  'congress’',
#  'choosen',
#  'camera”',
#  'pu',
#  ...}

# %%
tknzr = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)

list_train = []
for tweet in train['tweet']:
    for token in tknzr.tokenize(tweet):
        list_train.append(token)
              
list_test = []
for tweet in test_a['tweet']:
    for token in tknzr.tokenize(tweet):
        list_test.append(token)
        
print("Vocab size:", len(set(list_train)))
print("Vocab size:", len(set(list_test)))

set(list_train)-set(list_test)
# Out:
# Vocab size: 20944
# Vocab size: 5726
# {'repro',
#  'yayay',
#  'africa',
#  'ferries',
#  '\U0001f92a',
#  'deletion',
#  'bureau',
#  '#gender',
#  'psychic',
#  'troubleshooting',
#  'alternative',
#  'ronald',
#  'out-bekhit',
#  '😝',
#  'dnt',
#  'funner',
#  'billy',
#  'henderson',
#  'multicultural',
#  'prettiest',
#  '🚑',
#  'decommissioned',
#  'impeccable',
#  'novel',
#  'saudis',
#  '#bigmoney',
#  '#walkingaway',
#  'realtor',
#  'splitting',
#  'telly',
#  '55yr',
#  'sanctity',
#  'extremistische',
#  'shitty',
#  'papers',
#  'mbappe',
#  'youre',
#  't-be-evil-corp',
#  'toolbox',
#  'ig',
#  'cave',
#  'visually',
#  'rabbit',
#  'barrel',
#  'tristan',
#  '#philadelphia',
#  'gates',
#  'benny',
#  'hilariously',
#  'radicalized',
#  'unethical',
#  'portraying',
#  'indicating',
#  'psuedo',
#  '#bus',
#  'reorganize',
#  '20-0',
#  'pictures',
#  '81st',
#  'well-fostered',
#  '#ericholdercrimes',
#  'lawsuit',
#  'commercials',
#  'comfortable.hey',
#  'dez',
#  '#vaterans',
#  'referred',
#  'outlier',
#  '✍',
#  'rga',
#  'lackeys',
#  'ripe',
#  'ainge',
#  '#sonnykiriakis',
#  'assumptions',
#  'cheeseburger',
#  'menopausal',
#  "gov't",
#  'communicate',
#  'clear',
#  '#ginsbergisnext',
#  'positive',
#  '#countrybeforeparty',
#  '#cdnhist',
#  '#documented',
#  'admired',
#  'supervision',
#  'protocols',
#  'guarding',
#  'missouri',
#  'finishers',
#  'pig',
#  'walls',
#  'bin',
#  'sads',
#  'fashions',
#  'subscribers',
#  'amongst',
#  "o'keefe",
#  'howard',
#  '🇵',
#  '#jesusisback',
#  'annually',
#  'kathryn',
#  'connelly',
#  'biter',
#  'half',
#  '#theresamay',
#  'dots',
#  'toxic',
#  'mensch',
#  'convicts',
#  'lengths',
#  'cheney',
#  'mad',
#  'shared',
#  'horrid',
#  'preseason',
#  'winnig',
#  'exams',
#  'roy',
#  'hosting',
#  'weaponised',
#  '#kavanaughconfirmationhearing',
#  'bullying',
#  'worshippers',
#  'improved',
#  '10.5',
#  'gangsta',
#  'rezz',
#  'relativizing',
#  'sport',
#  'imagery',
#  'establishing',
#  'repug',
#  'bodyguard',
#  'lbj',
#  'size',
#  '#christineblaseykavanaugh',
#  'heh',
#  'aries',
#  'panel',
#  'stolen',
#  'sections',
#  'deary',
#  'db',
#  'exec',
#  'acknowledges',
#  'kampf',
#  'skies',
#  'privitizing',
#  'them.he',
#  'extrapolate',
#  'queens',
#  'salaries',
#  'aura',
#  'divide',
#  'folding',
#  '#nocaliforniademocrats',
#  '#frankoz',
#  'jealousy',
#  'baz',
#  '#starvation',
#  'paint',
#  'flirting',
#  'mk',
#  'juan',
#  'cabinet',
#  '#twittershouldbe',
#  'amazingly',
#  'lightweight',
#  'deliberate',
#  'true.women',
#  'jr',
#  'rss',
#  'leave-just',
#  'kool',
#  'outdone',
#  '40s',
#  'defends',
#  'isle',
#  'epitomizes',
#  'humour',
#  'forging',
#  '#enddaca',
#  'organiser',
#  'requisite',
#  'dickbrain',
#  'usko',
#  '🚨',
#  'shit-smear',
#  "everyone's",
#  '#pantsonfire',
#  'doggie',
#  'inauguration',
#  'dat',
#  'map',
#  'extrajudicial',
#  'ala',
#  'convey',
#  'deirdre',
#  'kaise',
#  'kermit',
#  'uighur',
#  '#uspolitics',
#  'sponsor',
#  'borrower',
#  'srsly',
#  'theories.most',
#  'birch',
#  'philippines',
#  'jail',
#  'kendall',
#  'chunk',
#  'cred',
#  'mix',
#  'suspicious',
#  'ehave',
#  'bhakt',
#  'lions',
#  'greasy',
#  'evolving',
#  'moved',
#  '#luciferiarising',
#  'carlos',
#  '#gunsensecandidates',
#  'monologues',
#  'faerie',
#  '#hadexincursion',
#  'disrespectful',
#  'memorable',
#  'diss',
#  'prosecuting',
#  'migration',
#  'hiya',
#  'messed',
#  '#cheating',
#  '#sb100',
#  'deemed',
#  'herrera',
#  'nationalised',
#  '#channel4',
#  'regime',
#  'picturing',
#  'dion',
#  'cus',
#  'egghead',
#  '！',
#  'lit',
#  'thin',
#  'lining',
#  'nerd',
#  'opportunist',
#  'mcfartney',
#  'booter',
#  'disasters',
#  '#resisttrump',
#  'compliance',
#  'fussing',
#  '#letsgoshooting',
#  'ultra',
#  'merck',
#  'bout',
#  'gestapo',
#  '#priorities',
#  'colleen',
#  'ecstatic',
#  '#mifsud',
#  '38',
#  'tongue-in-cheek',
#  'umm',
#  'marginalizing',
#  'doctrine',
#  'competence',
#  'reprisal',
#  'speculate',
#  '\U0001f6f8',
#  'betting',
#  'bashing',
#  'aca',
#  'overtime',
#  'assaulted',
#  'skepticism',
#  '#tyrannical',
#  'admin',
#  'starfire',
#  'satisfies',
#  'additional',
#  'methodical',
#  'hangin',
#  'bravos',
#  'eights',
#  'disgrace-without',
#  'holster',
#  'posting',
#  'pawn',
#  'messaged',
#  'demonizes',
#  'studied',
#  'bhajpaa',
#  'civilised',
#  'campers',
#  'regrettable',
#  'yessir',
#  'pilled',
#  'rival',
#  'cdns',
#  'disappointing',
#  'medi-care',
#  '#guantanamo',
#  'evilness',
#  'treatin',
#  'kahlili',
#  'theyll',
#  'defamation',
#  'helpful',
#  '0/10',
#  'leopard',
#  '#mariokart',
#  'neck',
#  'graham',
#  'revoke',
#  'lineswoman',
#  'gullibles',
#  'streams',
#  'twists',
#  '5.0',
#  'waffen',
#  'tana',
#  'pc',
#  'passive',
#  'authority',
#  'reportedly',
#  'disproven',
#  'accuracy',
#  'ko',
#  '#sugardaddyneeded',
#  'determined',
#  'timed',
#  'offender',
#  'z-jail',
#  'excommunicate',
#  'blender',
#  '#femfrauds',
#  'axis',
#  '#victims',
#  'etiquette',
#  'cure',
#  'cj',
#  'corrections',
#  'separation',
#  '🍿',
#  'filter',
#  'rider',
#  'jacobite',
#  '#firearms',
#  'eirc',
#  'lead',
#  'royce',
#  'obscenities',
#  'bow',
#  'antinatalist',
#  'jim',
#  'novemeber',
#  'boards',
#  'champion',
#  'condensed',
#  'beefing',
#  'servers',
#  'huffing',
#  'shev',
#  'disappointment',
#  '208',
#  'hook',
#  '#jesuiten',
#  'disturbed',
#  'cobra',
#  'narrow',
#  'couch',
#  'equivalency',
#  '🚂',
#  'prelude',
#  'weirdos',
#  'complacency',
#  '#medicaid',
#  'misinterpret',
#  'dubakoor',
#  'becoz',
#  '#russia',
#  'reliever',
#  'xilhatarra',
#  'strait',
#  'inhales',
#  'variety',
#  'subsidised',
#  'barun',
#  '#nomorelevis',
#  'icecream',
#  'meaningless',
#  'asphalt',
#  '#whysjamescryin',
#  'demon-craps',
#  'softly',
#  'underoath',
#  '🤗',
#  'cuba',
#  'categorizes',
#  'low-growth',
#  'nowheresland',
#  'connecting',
#  '🍻',
#  'shiny',
#  'nymphet',
#  'freeze',
#  '#manaforttrial',
#  'pounded',
#  'disco',
#  'avi',
#  'cosy',
#  'scalise',
#  'niggaz',
#  'vibe',
#  '#xrp',
#  'playoffs',
#  'rug',
#  'weenie',
#  'foriegn',
#  'cube',
#  'conclude',
#  'assurances',
#  'stomped',
#  'dismembered',
#  'corporates',
#  'screened',
#  'smg',
#  'one--it',
#  'transphobic',
#  'rank',
#  'throwing',
#  'fabricates',
#  'slouches',
#  '6/7',
#  'disagreed',
#  'dolt',
#  'ihmykgodoosj',
#  'joyful',
#  'fundamental',
#  'babysitting',
#  'side-note',
#  'abhorrent',
#  'shuting',
#  'parasitic',
#  'publicizing',
#  'pro-gun',
#  'pentagon',
#  'apartaments',
#  'vg',
#  'postal',
#  'ligic',
#  'wisely',
#  'links',
#  'generated',
#  'ong',
#  'renfrew',
#  'domo',
#  'handshake',
#  '#stcshooting',
#  'insurance',
#  'messiness',
#  'watered',
#  '❌',
#  'militant',
#  'clingvto',
#  'cart',
#  'visibly',
#  'deter',
#  'appease',
#  '#couple',
#  'instruct',
#  'limp',
#  '187',
#  'bites',
#  '1-2',
#  'toad',
#  'ost',
#  '302',
#  'caribbean',
#  'catfight',
#  'amends',
#  'modest',
#  '#illegalalien',
#  'corruptions',
#  'lmfaoo',
#  'jurist',
#  'biblical',
#  'subpoenas',
#  '#writerwednesday',
#  'dealers',
#  'goldwater',
#  'kraber',
#  'commerce',
#  'plagued',
#  'envy',
#  '23:57',
#  'reee',
#  'physically',
#  'posing',
#  'rolling',
#  'weirdly',
#  'subverting',
#  'validity',
#  'wider',
#  'duet',
#  'mo',
#  'reunion',
#  'poly',
#  'substance',
#  '#idiotalert',
#  'foremost',
#  'mentions',
#  'konjam',
#  'glare',
#  'affects',
#  'locally',
#  'outcome',
#  "shouldn't",
#  'mariota',
#  '👂',
#  '#roseannebarr',
#  'regulation',
#  'liberaltarian',
#  'pinstriped',
#  '105',
#  'reminds',
#  'wheeew',
#  'h3ll',
#  'misuse',
#  '#thewallstreetjournal',
#  'yooo',
#  'fueling',
#  'punish',
#  'batsht',
#  '#independents',
#  'inbred',
#  '#unbelievable',
#  'albert',
#  'lazy',
#  'accomplish',
#  'logic',
#  '#globalization',
#  'feminazis',
#  'dangerously',
#  'attracted',
#  '#beauty',
#  'satochi',
#  'supermajority',
#  'pas',
#  'roughed',
#  'swords',
#  '#islamophobia',
#  'disqualifying',
#  'dildo',
#  'farmer',
#  'percentile',
#  'uncivil',
#  'sandyhook',
#  'rocket',
#  'repercussions',
#  'illustration',
#  'generic',
#  'pretend',
#  'spoil',
#  'cars',
#  '⭐',
#  'underestimate',
#  'sparking',
#  'paths',
#  'prz',
#  '106m',
#  'celebrating',
#  '#everybodyin',
#  '#mru',
#  'misdirection',
#  'fiasco',
#  'achieve',
#  'hollowing',
#  'barn',
#  'nearly-zero',
#  'payment',
#  'chemistry',
#  'libel',
#  'pbs',
#  'explicitly',
#  '#womenshouldruletheworld',
#  '#factsonly',
#  'pumpkin',
#  'cherish',
#  'internet.anti',
#  'mickie',
#  '#makeamericastrongagain',
#  'towns',
#  'fixed',
#  "nobody's",
#  'kellyanne',
#  'inthe',
#  'cues',
#  'hogwash',
#  'nikki',
#  'tit',
#  'unflattering',
#  '#expropriate',
#  'basing',
#  '#maga2kag',
#  'cars--seem',
#  '#marketing',
#  'removal',
#  '#agsessions',
#  'beaware',
#  'yelped',
#  'squashed',
#  '#voterepublican2018',
#  'ragging',
#  'sesame',
#  '#trumptariffs',
#  'tenets',
#  'ump',
#  'sins',
#  '#vaccineholocaust',
#  'copy',
#  'develop',
#  'bday',
#  'darn',
#  'vetting',
#  'visited',
#  'assist',
#  'rené',
#  'doomsday',
#  'demagogues',
#  'entertainer',
#  'grape',
#  'logo',
#  'hopefully',
#  'count',
#  'rural',
#  'leaked',
#  'histrionic',
#  'flirty',
#  'shaft',
#  'tw115',
#  'helpless',
#  "kkk's",
#  'notified',
#  'command',
#  'preorder',
#  'underlying',
#  'clouds',
#  'kurt',
#  'co-operate',
#  'rebounded',
#  'nu',
#  'sober',
#  'obozo',
#  'hasty',
#  'vying',
#  'abbott',
#  'gabole',
#  '#devilyouloseagain',
#  'contemptuously',
#  '👯',
#  'wanka',
#  '130',
#  'oakland',
#  'shon',
#  '#keithellison',
#  'contradictions',
#  'cu',
#  'slavery',
#  'assumes',
#  'punished',
#  'railed',
#  'unadulterated',
#  '14th',
#  'ddsl',
#  'fits',
#  '#redtsunami2018',
#  'extraordinarily',
#  'dated',
#  'conner',
#  'cooper',
#  'interviews',
#  'distinguish',
#  'hazard',
#  '#imwithdave',
#  '#lyingskank',
#  '#groominggangs',
#  '7k',
#  'shaming',
#  'pog',
#  'pmjt',
#  'boi',
#  'perpetuate',
#  'coddled',
#  'kakulitan',
#  'overlords',
#  'altar',
#  'hahah',
#  'controll',
#  'loot',
#  '💗',
#  'distorts',
#  'compose',
#  'vainly',
#  'power-we',
#  'showalter',
#  'sleeze',
#  'judiciary',
#  'ben',
#  '357',
#  'kansas',
#  'hyt',
#  '#swagodking',
#  'potion',
#  'limits',
#  'courthouse',
#  'knack',
#  'spoilt',
#  'disagreeing',
#  'binged',
#  'scrawny',
#  'nicco',
#  'backsides',
#  'temper',
#  'equipped',
#  'oligarchies',
#  'applebee',
#  'curb',
#  'kaam',
#  '2013',
#  '#mdzs2018',
#  'shaping',
#  '#usaguard',
#  'getup',
#  'difficulties',
#  'beg',
#  'hubris',
#  'perverts',
#  'lasa',
#  'attest',
#  'selena',
#  'deficient',
#  'demonized',
#  "nation's",
#  'pruitt',
#  '#brexitmeansbrexit',
#  'cavill',
#  'non-mmt',
#  "d's",
#  'act-aca',
#  'dirtbag',
#  'criticizes',
#  'pharisees',
#  'solve',
#  'wld',
#  'stream',
#  'canon',
#  'politicize',
#  'anonymously',
#  'hooo',
#  'conclusions',
#  '#txst',
#  'cater',
#  'facsicm',
#  'consider',
#  'sombody',
#  'singular',
#  '#secondammendment',
#  'frost',
#  'duckduckgo',
#  'delayed',
#  'charms',
#  'contemporary',
#  'diners',
#  'ocd',
#  'included',
#  'commuted',
#  '#christianmorals',
#  'losses',
#  'recovered',
#  'hooper',
#  'bidding',
#  'tc',
#  'deranged',
#  'overcome',
#  'tribes',
#  '#cdc',
#  'particratic',
#  'esteem',
#  'unelected',
#  "she'd",
#  'dumocrat',
#  'worded',
#  'discussing',
#  'favored',
#  'breaths',
#  'disrespects',
#  '#johnmccain',
#  'gifts',
#  'chart',
#  'inculcate',
#  'vendetta',
#  'flushing',
#  'charm',
#  'oral',
#  'benign',
#  'raises',
#  'happyhappy',
#  'cooked',
#  '#makeamericagreatagain',
#  'separations',
#  'uber',
#  '#tucker',
#  'municipal',
#  'leaf',
#  'call-up',
#  'ferengi',
#  'hello',
#  'booth',
#  'retiree',
#  '#institutionalracism',
#  'no-scope',
#  'tow',
#  'obtaining',
#  'bullcrap',
#  'appropiated',
#  '#kavenaughs',
#  'kogasas',
#  'rake',
#  "trudeau's",
#  '#nflwalkaway',
#  'barry',
#  'bestfriend',
#  "visa-mata's",
#  'hungrier',
#  'att',
#  'necessary',
#  'dennison',
#  'fleeted',
#  'glc',
#  'eveb',
#  'slaves',
#  'dopest',
#  'gasses',
#  '#makecaliforniagreatagain',
#  'eviction',
#  'kl',
#  'hidden',
#  'miserably',
#  'saysitall',
#  'cohorts',
#  '#lawenforcement',
#  'adorably',
#  'accordingly-you',
#  'asb',
#  'banbury',
#  'ju',
#  'retaliate',
#  'mxm',
#  'folded',
#  'semi',
#  '#killthezebras',
#  '🎈',
#  'invitation',
#  'blanche',
#  'afterward',
#  'skiddish',
#  '#tngop',
#  'wanker',
#  'griexsevia',
#  'dandruff',
#  'hmg',
#  'o-ren',
#  'wreath',
#  'golfing',
#  'pagan',
#  'tuition',
#  'demonstrates',
#  'guyyy',
#  'jihadist',
#  'europeans',
#  'spend',
#  'pander',
#  'roblox',
#  'ballistic',
#  '#twitterpurge',
#  'weez',
#  'fawningly',
#  'paperback',
#  'go-to',
#  '#professor',
#  'trademark',
#  'tmart',
#  'lotta',
#  '1.14',
#  'skeptical',
#  'mcdonald',
#  'duty',
#  'notebook',
#  'admins',
#  'hypnotized',
#  'tie',
#  'victimize',
#  'rao',
#  'triumph',
#  'degrees',
#  'meps',
#  'iniated',
#  'crypts',
#  'looney',
#  'parris',
#  'degenerates',
#  'delivered',
#  '🐉',
#  'relentless',
#  'believable',
#  'misogynistic',
#  'registrar',
#  'blanket',
#  '15th',
#  'returning',
#  'straightening',
#  'alcatraz',
#  'vid',
#  'sponsors',
#  'fuckbucket',
#  '43',
#  'stupidity',
#  'drove',
#  'flourishing',
#  'tamir',
#  '#jeremycorbyn',
#  '29',
#  'peterson',
#  'stood',
#  'signatures',
#  '#godblessourmilitary',
#  'capture',
#  'arizona',
#  'downloading',
#  'gonzalez',
#  'infringe',
#  'brave',
#  'admonish',
#  '23879',
#  'sponge',
#  'scrunchie',
#  'stepped',
#  'sided',
#  'bolaji',
#  '😚',
#  'ratbags',
#  'buzzwords',
#  'squirt',
#  'burden',
#  'motherfucker',
#  'scatter',
#  'landslide',
#  'primadonnas',
#  'reconnect',
#  'creates',
#  'african-american',
#  'profile',
#  'undermining',
#  '1994',
#  'liblabcon',
#  'breast',
#  'whiney',
#  'mehn',
#  'jamie',
#  'clash',
#  'sos',
#  'element',
#  '#liberalintolerance',
#  'justly',
#  'signals',
#  'relativists',
#  '#muelleriscomingforyoutoo',
#  'choosen',
#  '🐷',
#  'gropy',
#  'pu',
#  'harrowing',
#  'robin',
#  'tbf',
#  'alcantara',
#  'sucking',
#  'surpassing',
#  '#transport',
#  'ira',
#  'dabble',
#  'debunked',
#  ...}

# %%
occ_train = Counter(list_train)
occ_test = Counter(list_test)

occ_train.most_common()[-100:-1]
occ_train.most_common(100)
# Out:
# [('.', 14431),
#  ('the', 9067),
#  ('is', 6554),
#  ('to', 6317),
#  ('a', 5412),
#  ('you', 5290),
#  ('and', 5169),
#  ('!', 4814),
#  ('of', 3834),
#  ('are', 3601),
#  ('i', 3423),
#  ('he', 2976),
#  ('?', 2949),
#  ('that', 2829),
#  ('in', 2706),
#  ('’', 2574),
#  ('for', 2492),
#  ('she', 2476),
#  ('"', 2399),
#  ('it', 2304),
#  ('url', 2059),
#  ('this', 1853),
#  ('on', 1701),
#  ('...', 1664),
#  ('not', 1661),
#  ('they', 1555),
#  ('with', 1484),
#  ('have', 1467),
#  ('be', 1441),
#  ('liberals', 1380),
#  ('gun', 1368),
#  ('so', 1274),
#  ('all', 1249),
#  (',', 1235),
#  ('control', 1226),
#  ('your', 1174),
#  ('what', 1145),
#  ('like', 1111),
#  ('antifa', 1098),
#  ('but', 1086),
#  ('we', 1078),
#  ('as', 1069),
#  ('s', 1066),
#  ('just', 1016),
#  ('about', 1014),
#  ('her', 1014),
#  ('was', 984),
#  ('t', 980),
#  ('if', 973),
#  ('will', 958),
#  ('do', 946),
#  ('who', 930),
#  ('people', 911),
#  ('conservatives', 871),
#  ('no', 869),
#  ('#maga', 823),
#  ('his', 800),
#  ('at', 775),
#  ('my', 757),
#  ('how', 756),
#  ('from', 754),
#  ('by', 753),
#  ('or', 752),
#  ('-', 740),
#  ('has', 736),
#  ('can', 718),
#  ('an', 706),
#  ('out', 692),
#  ('up', 690),
#  ('their', 689),
#  ('&', 677),
#  ('get', 662),
#  ('me', 661),
#  ('know', 639),
#  ('one', 636),
#  ('why', 623),
#  ('when', 608),
#  ('more', 601),
#  ('because', 594),
#  ('him', 587),
#  ('trump', 572),
#  ('now', 565),
#  ('them', 557),
#  ('think', 555),
#  ('there', 539),
#  ('would', 524),
#  ("don't", 520),
#  ('should', 494),
#  (':', 477),
#  ('😂', 470),
#  ('right', 465),
#  ('good', 462),
#  ('our', 460),
#  (')', 432),
#  ('..', 430),
#  ('only', 426),
#  ('(', 415),
#  ("it's", 413),
#  ('/', 404),
#  ('us', 400)]

# %%
occ_test.most_common(10)
occ_test.most_common()[-100:-1]
# Out:
# [('net', 1),
#  ('designed', 1),
#  ('close-up', 1),
#  ('excessive', 1),
#  ('outlook', 1),
#  ('purple', 1),
#  ('highest', 1),
#  ('#ncwx', 1),
#  ('#nrv', 1),
#  ('#rke', 1),
#  ('#feckless', 1),
#  ('waste', 1),
#  ('expending', 1),
#  ('mentally', 1),
#  ('unstable', 1),
#  ('cowards', 1),
#  ('#emmys2018', 1),
#  ('sanda', 1),
#  ('ho', 1),
#  ('asia', 1),
#  ('description', 1),
#  ('sweetest', 1),
#  ("thursday's", 1),
#  ('nursing', 1),
#  ('10:15', 1),
#  ('afterwards', 1),
#  ('tests', 1),
#  ('lunch', 1),
#  ('11:50', 1),
#  ('strange', 1),
#  ('unusual', 1),
#  ("i'am", 1),
#  ('sleepy', 1),
#  ('bot', 1),
#  ('cuddles', 1),
#  ('browning', 1),
#  ('fcs', 1),
#  ('coverage', 1),
#  ('videos', 1),
#  ('#textureontherunway', 1),
#  ('nyc', 1),
#  ('emmy', 1),
#  ('winner', 1),
#  ('fierce', 1),
#  ('#ctriders', 1),
#  ('friday', 1),
#  ('enjoy', 1),
#  ('#readanewbookmonth', 1),
#  ('patio', 1),
#  ('cup', 1),
#  ('month', 1),
#  ('butch', 1),
#  ('receives', 1),
#  ('riled', 1),
#  ('theme', 1),
#  ('repeat', 1),
#  ('rangers', 1),
#  ('replacement', 1),
#  ('fortifying', 1),
#  ('longer', 1),
#  ('taste', 1),
#  ('#team4thebeez', 1),
#  ('#dumped2die', 1),
#  ('grief', 1),
#  ('terrified', 1),
#  ('#nokillshelternation', 1),
#  ('#heroes2animals', 1),
#  ('#despicabledems', 1),
#  ('rifles', 1),
#  ('distorted', 1),
#  ('gun-control', 1),
#  ('confirmation', 1),
#  ('#meetthespeakers', 1),
#  ('oiw', 1),
#  ('finpact', 1),
#  ('financial', 1),
#  ('technologies', 1),
#  ('senior', 1),
#  ('advisor', 1),
#  ('sustainable', 1),
#  ('worked', 1),
#  ('climate', 1),
#  ('thina', 1),
#  ('#oiw2018', 1),
#  ('unfollowed', 1),
#  ('merlin', 1),
#  ("covinsky's", 1),
#  ('psisly', 1),
#  ('sequel', 1),
#  ('announcement', 1),
#  ('ive', 1),
#  ('witty', 1),
#  ('tatbilb', 1),
#  ('drained', 1),
#  ('reich', 1),
#  ('indoctrination', 1),
#  ('minorities', 1),
#  ('total', 1),
#  ('understanding', 1)]

# %% [markdown]
# ### Emojis and emoticons

# %%
def get_emojis_emoticons(data):
    '''
    Returns all_emojis, id_emojis, all_emoticons, id_emoticons
    
    :param data: Complete dataset
    '''
    
    all_emojis = []
    id_emojis = []

    all_emoticons = []
    id_emoticons = []
    
    all_data = ' '.join(list(data['tweet']))
    
    for tweet_id, tweet_text in enumerate(data['tweet']):

        #Package: emojis
        emo = emojis.get_all(tweet_text)

        if len(list(emo))>=1:
            for emoji in list(emo):
                all_emojis.append(emoji)
                id_emojis.append(tweet_id)

        #Package: emot    
        try:
            emoticons = emot.emoticons(tweet_text)['value']

            if len(list(emoticons))>=1:

                for emoticon in list(emoticons):
                    all_emoticons.append(emoticon)
                    id_emoticons.append(tweet_id)
        except:
            pass

    print("Count number of tweets with emojis: {} ({}%)".format(len(Counter(id_emojis).keys()), round(100*len(Counter(id_emojis).keys())/len(data), 2)))

    print("Count emojis: ", emojis_extra.count(all_data))
    print("Count unique emojis: ", emojis_extra.count(all_data, unique=True))
    
    print("Count number of tweets with emoticons: {} ({}%)".format(len(Counter(id_emoticons).keys()), round(100*len(Counter(id_emoticons).keys())/len(data), 3)))

    print("Count emoticons: ", len(all_emoticons))
    print("Count unique emoticons: ", len(Counter(all_emoticons).keys()))
    
    print(set(id_emojis).intersection(set(id_emoticons)))

    occ_emojis = Counter(all_emojis)
    print(occ_emojis.most_common())

    occ_emoticons = Counter(all_emoticons)
    print(occ_emoticons.most_common())
    
    return occ_emojis, occ_emoticons, all_emojis, id_emojis, all_emoticons, id_emoticons

# %%
all_ooc_emojis, all_occ_emoticons, all_emojis, id_emojis, all_emoticons, id_emoticons = get_emojis_emoticons(train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-f3be01093750> in <module>
# ----> 1 all_ooc_emojis, all_occ_emoticons, all_emojis, id_emojis, all_emoticons, id_emoticons = get_emojis_emoticons(train)
#
# <ipython-input-13-d336f19c9d74> in get_emojis_emoticons(data)
#      17
#      18         #Package: emojis
# ---> 19         emo = emojis.get_all(tweet_text)
#      20
#      21         if len(list(emo))>=1:
#
# AttributeError: module 'emojis' has no attribute 'get_all'

# %%
for emoji, count in all_ooc_emojis.most_common(10):
    print(emoji, "&", count, "&", emojis_extra.decode(emoji), "\\\\")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-9b9350f418a5> in <module>
# ----> 1 for emoji, count in all_ooc_emojis.most_common(10):
#       2     print(emoji, "&", count, "&", emojis_extra.decode(emoji), "\\\\")
#
# NameError: name 'all_ooc_emojis' is not defined

# %%
for emoji, count in all_ooc_emojis.most_common(10):
    print(emojis_extra.decode(emoji), "&", count, "\\\\")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-5b31d41ba1fa> in <module>
# ----> 1 for emoji, count in all_ooc_emojis.most_common(10):
#       2     print(emojis_extra.decode(emoji), "&", count, "\\\\")
#
# NameError: name 'all_ooc_emojis' is not defined

# %%
print(max(Counter(id_emojis).values()))
print(min(Counter(id_emojis).values()))
print(sum(Counter(id_emojis).values())/len(Counter(id_emojis).keys()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-3e6dd1a31f56> in <module>
# ----> 1 print(max(Counter(id_emojis).values()))
#       2 print(min(Counter(id_emojis).values()))
#       3 print(sum(Counter(id_emojis).values())/len(Counter(id_emojis).keys()))
#
# NameError: name 'id_emojis' is not defined

# %%
Counter(id_emojis).most_common(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-beaa862c803a> in <module>
# ----> 1 Counter(id_emojis).most_common(10)
#
# NameError: name 'id_emojis' is not defined

# %%
train['tweet'][11071]
# Out:
# '@USER @USER #MAGA #KAG #TRUMP2020 #TRUMP=HERO #TRUMP=LEADER #WELUVTRUMP 🇺🇸❤️🇺🇸❤️🇺🇸❤️🇺🇸❤️🇺🇸❤️🇺🇸❤️🇺🇸❤️🇺🇸❤️🇺🇸❤️🇺🇸❤️🇺🇸❤️🇺🇸❤️🇺🇸❤️🇺🇸❤️🇺🇸❤️🇺🇸 URL'

# %%
print("\n Emojis \n ------")
print(train.iloc[id_emojis]['subtask_a'].value_counts(normalize=True))
print(train.iloc[id_emojis]['subtask_a'].value_counts())

print("\n Emoticons \n ---------")
print(train.iloc[id_emoticons]['subtask_a'].value_counts(normalize=True))
print(train.iloc[id_emoticons]['subtask_a'].value_counts())
# Out:
#  Emojis
#  ------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-934940d10628> in <module>
#       1 print("\n Emojis \n ------")
# ----> 2 print(train.iloc[id_emojis]['subtask_a'].value_counts(normalize=True))
#       3 print(train.iloc[id_emojis]['subtask_a'].value_counts())
#       4
#       5 print("\n Emoticons \n ---------")
#
# NameError: name 'id_emojis' is not defined

# %%
all_ooc_emojis, all_occ_emoticons, all_emojis, id_emojis, all_emoticons, id_emoticons = get_emojis_emoticons(train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-f3be01093750> in <module>
# ----> 1 all_ooc_emojis, all_occ_emoticons, all_emojis, id_emojis, all_emoticons, id_emoticons = get_emojis_emoticons(train)
#
# <ipython-input-13-d336f19c9d74> in get_emojis_emoticons(data)
#      17
#      18         #Package: emojis
# ---> 19         emo = emojis.get_all(tweet_text)
#      20
#      21         if len(list(emo))>=1:
#
# AttributeError: module 'emojis' has no attribute 'get_all'

# %%
all_ooc_emojis_test, all_occ_emoticons_test, all_emojis_test, id_emojis_test, all_emoticons_test, id_emoticons_test = get_emojis_emoticons(test_a)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-3a3709362112> in <module>
# ----> 1 all_ooc_emojis_test, all_occ_emoticons_test, all_emojis_test, id_emojis_test, all_emoticons_test, id_emoticons_test = get_emojis_emoticons(test_a)
#
# <ipython-input-13-d336f19c9d74> in get_emojis_emoticons(data)
#      17
#      18         #Package: emojis
# ---> 19         emo = emojis.get_all(tweet_text)
#      20
#      21         if len(list(emo))>=1:
#
# AttributeError: module 'emojis' has no attribute 'get_all'

# %%
print("\n Emojis \n ------")
print(test_a.iloc[id_emojis_test]['subtask_a'].value_counts(normalize=True))
print(test_a.iloc[id_emojis_test]['subtask_a'].value_counts())

print("\n Emoticons \n ---------")
print(test_a.iloc[id_emoticons_test]['subtask_a'].value_counts(normalize=True))
print(test_a.iloc[id_emoticons_test]['subtask_a'].value_counts())
# Out:
#  Emojis
#  ------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-e11982fbd2c8> in <module>
#       1 print("\n Emojis \n ------")
# ----> 2 print(test_a.iloc[id_emojis_test]['subtask_a'].value_counts(normalize=True))
#       3 print(test_a.iloc[id_emojis_test]['subtask_a'].value_counts())
#       4
#       5 print("\n Emoticons \n ---------")
#
# NameError: name 'id_emojis_test' is not defined

# %% [markdown]
# ### Emoticons + intersection

# %%
#Emoji and emoticon in same tweet
print(set(id_emojis).intersection(set(id_emoticons)))

for tweet_id in list(set(id_emojis).intersection(set(id_emoticons))):
    ex = train['tweet'][tweet_id]
    print(tweet_id)
    print(ex)
    
for tweet_id in list(id_emoticons):
    ex = train['tweet'][tweet_id]
    print("id:",tweet_id)
    print("tweet:",ex)
    print("emoticons:",emot.emoticons(ex)['value'])
    print("\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-271ab9f6083e> in <module>
#       1 #Emoji and emoticon in same tweet
# ----> 2 print(set(id_emojis).intersection(set(id_emoticons)))
#       3
#       4 for tweet_id in list(set(id_emojis).intersection(set(id_emoticons))):
#       5     ex = train['tweet'][tweet_id]
#
# NameError: name 'id_emojis' is not defined

# %% [markdown]
# ## Hashtags

# %%
all_hashtags = []
all_id_hashtags = []

for i, tweet in enumerate(train['tweet']):
    hashtags = re.findall(r"#\w+", tweet)
    
    if len(hashtags)>0:
        print(hashtags)
        for hashtag in hashtags:
            all_hashtags.append(hashtag)
            #print(segment(hashtag))
        all_id_hashtags.append(i)
# Out:
# ['#MAGA', '#Trump2020']
# ['#Amazon', '#MAGA', '#KAG', '#CHINA', '#TCOT']
# ['#LooneyLeft', '#Liberals', '#Qproofs', '#TrudeauMustGo']
# ['#Kavanaugh', '#confirmed', '#DemsareFrauds', '#DemsAreDone', '#WalkAwayDemocrats2018', '#redwave', '#VoteRedSaveAmerica', '#trumptrain', '#MAGA']
# ['#DeepStateCorruption']
# ['#MAGA']
# ['#guncontrol', '#cdnpoli', '#cdnhist']
# ['#PutUpOrShutUp', '#Kavanaugh', '#MAGA', '#CallTheVoteAlready']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#President', '#Trump', '#Kavanaugh', '#MAGA', '#DEMSUCK']
# ['#racism', '#Windrush', '#Grenfell', '#alloutpolitics', '#politicslive', '#PMQs']
# ['#KavanaughConfirmation', '#woke']
# ['#RuleOfLaw', '#MeToo', '#CountryOverParty', '#WithdrawKavanaugh', '#StopKavanaugh']
# ['#AMERICAFIRST', '#USA', '#MAGA', '#LEADERSHIP', '#RESPECT', '#ECONOMY', '#JOBS', '#PEACEthruSTRENGTH', '#GOD', '#BLESS', '#TRUMP', '#THEUSA']
# ['#FalseProphet', '#Lunatic']
# ['#Soros']
# ['#GUNCONTROL']
# ['#WalkAway']
# ['#Toxictory', '#Toriesmustgo', '#DissolveTheUnion']
# ['#Manmarziyaan']
# ['#Hypocrickets']
# ['#Antifa']
# ['#Maga', '#QAnon', '#WakeUpAmerica']
# ['#MAGA', '#TRUMP']
# ['#Protests', '#Sunderland', '#football', '#flag', '#WestBrom', '#MAGA', '#MEGA', '#MBGA', '#MCGA', '#Conservatives', '#Patriots', '#Muslims', '#FarLeft', '#Leftists', '#CivilWar']
# ['#TwitterLeftBias']
# ['#democrats', '#MAGA', '#NAACP']
# ['#ableg', '#cdnpoli']
# ['#LeviStrauss']
# ['#MAGA', '#tcot']
# ['#Antifa']
# ['#Conservatives', '#binnedBoris']
# ['#DEMS', '#Obama', '#CrookedHillary', '#MAGA', '#TRUMP']
# ['#MAGA']
# ['#ChristineBlaseyFord', '#ConfirmKavanaugh', '#MAGA', '#WeakRinos', '#Republicans']
# ['#Liberal', '#WakeUpAmerica', '#DEM', '#MAGA']
# ['#MAGA']
# ['#MAGA']
# ['#FireMorningJoe']
# ['#gop']
# ['#KamalaHarris']
# ['#MAGA']
# ['#manifesto', '#HostileEnvironment', '#PriceOnLove', '#SkypeFamilies']
# ['#WhatILearnedToday']
# ['#MAGA']
# ['#ANTIFA']
# ['#maga', '#christineford', '#trump2020', '#tcot', '#ccot', '#AmericaFirst', '#Patriots', '#BrettKavanaugh']
# ['#MAGA']
# ['#Kavanaugh']
# ['#MAGA']
# ['#StrataData', '#AI', '#data', '#hairball', '#Cognitive', '#machinelearning', '#Governance', '#data']
# ['#LibFAIL']
# ['#Health', '#Nature', '#UK', '#US']
# ['#puertorico', '#diásporaenresistencia']
# ['#Antifa', '#Q', '#QAnon', '#TheGreatAwakening', '#CommieClowns', '#ResistanceRises', '#Resistance']
# ['#QANON', '#MAGA', '#GREATAWAKENING']
# ['#Fantastic', '#MAGA', '#Patriots']
# ['#MAGA']
# ['#teacherlife', '#prayalloftheprayers']
# ['#WhysJamesCryin']
# ['#ThursdayThoughts']
# ['#2A']
# ['#DisarmHate']
# ['#ConfirmBrettKavanaughNow']
# ['#MAGA', '#qanon', '#DrainTheDeepState', '#DrainTheSwamp']
# ['#American', '#truth', '#DrainTheDeepState', '#MAGA', '#Trump2020', '#KAG']
# ['#SJW', '#Paedophilia', '#Hollywood', '#TV', '#Movies', '#Gaming', '#Politics', '#Comics', '#Police', '#PublicAuthorities', '#Councils', '#DWP', '#DWPCrimes', '#CatholicChurch', '#Church', '#Vatican', '#Islam', '#Muslims', '#NHS', '#MBGA', '#Conservatives']
# ['#brexitshambles', '#BrexitMeansBrexit']
# ['#science', '#ecology', '#health', '#nature']
# ['#ClintonFoundation', '#MAGA', '#ClintonCrimes']
# ['#MAGA']
# ['#VA10']
# ['#oshaeterry', '#ThugLife', '#Criminal', '#MAGA', '#MAGA2020', '#MAGARallyRules', '#TexasPolice']
# ['#MAGA']
# ['#VoteDemsOut', '#VoteRed2018', '#TheRainMakers', '#QAnon', '#MAGA', '#WWG1WGA']
# ['#remain']
# ['#proudtobeBritish']
# ['#NHS']
# ['#Brexit']
# ['#FrankOz', '#DefundPBS']
# ['#VoteRedToSaveAmerica', '#KAG2018', '#MAGA']
# ['#DougFord']
# ['#MAGA']
# ['#MAGA', '#WINNING', '#REDWAVERISING2018', '#ScotusKavenaugh']
# ['#BrexitBritain']
# ['#Tcot', '#ccot', '#MAGA', '#KAG', '#Qanon', '#WalkAway', '#WWG1WGA', '#Kavanaugh']
# ['#fordnation', '#onpoli', '#Conservatives', '#Conservative', '#onpc']
# ['#NEverTrump']
# ['#MAGA']
# ['#Trump', '#MAGA']
# ['#FLOTUSrocks', '#MAGA']
# ['#NikeAd', '#BoycottNFL', '#BoycottNike', '#maga']
# ['#FACT']
# ['#MAGA']
# ['#MustVote2018', '#Republicans', '#WakeUpRepublicans', '#Conservatives', '#MAGA']
# ['#deepstate', '#ObamaWorstPresidentEver']
# ['#Parents', '#victims', '#gun']
# ['#MAGA', '#WINNING']
# ['#CloserNation', '#MAGA', '#QAnon']
# ['#Unbelievable', '#liberallosers', '#Trumpman', '#MAGA', '#DrainTheSwamp']
# ['#REDtsunami2018', '#TRUMP2020']
# ['#fakenews', '#cdnpoli']
# ['#HYPOCRITICAL']
# ['#Crypt', '#agentofChaurch']
# ['#Medicare', '#Medicaid', '#WelfareFoAll']
# ['#mybubblygirl', '#anupama', '#dreamgirl', '#BCO']
# ['#MAGA']
# ['#DangerousDemocrats', '#maga']
# ['#GAPBeLike']
# ['#writerwednesday']
# ['#MAGA', '#WWG1WGA']
# ['#DeepState']
# ['#MAGA']
# ['#Florence', '#NBCCT']
# ['#QAnon', '#MAGA', '#Trump', '#WWG1WGA', '#GreatAwakening', '#pray']
# ['#Funny', '#Hilarious', '#Meme', '#Brexit', '#Remainers', '#Leftists', '#HardBrexit', '#MBGA', '#MAGA', '#MCGA', '#MEGA', '#Conservatives', '#Patriots']
# ['#Socialist', '#Liberals', '#Socialism', '#Emmys', '#TuesdayThoughts', '#GlobalCitizen', '#Elections2018']
# ['#MAGA']
# ['#SCOTUS', '#HighTechLynching', '#MAGA', '#ConfirmKavanaugh', '#DJT', '#Kavanaugh', '#MeToo']
# ['#USA', '#UK', '#Europe', '#Australia', '#MAGA', '#MEGA', '#MBGA', '#MCGA', '#Conservatives', '#Patriots', '#Celebrities']
# ['#FakeNews']
# ['#Democracy']
# ['#trudeau', '#qanon', '#cbc', '#maga', '#ctv', '#bbc', '#tcot']
# ['#MAGA']
# ['#BeneathHumanity']
# ['#DianeFeinstein', '#ClarenceThomas', '#VoteRed2018', '#KAG', '#ConfirmKavanaugh', '#ConfirmCoachK', '#MAGA']
# ['#beaboutit']
# ['#TheDeepState', '#Jesuiten', '#Cabal', '#satanists', '#NWO', '#KalergiPlan', '#KalergiPreis', '#WhiteGenocide', '#COMMUNISM', '#Antifa', '#AlbertPike1871', '#DrainTheSwamp', '#LockThemAllUp', '#Guantanamo', '#EXPROPRIATE', '#QAnon', '#POTUS45', '#Trump2020']
# ['#MAGA']
# ['#RedWave']
# ['#OpenSelection']
# ['#DrainTheDeepState', '#crookedmedia']
# ['#NY']
# ['#VegasShooting']
# ['#DueProcess', '#Conservatives', '#documented', '#Democrat', '#DoubleStandards', '#ConfirmKavanaughNow']
# ['#RSSReachesOut']
# ['#POTUS', '#MAGA']
# ['#schiff4brains', '#MAGA', '#TRUMP2020', '#schiff4brains']
# ['#prouduncle']
# ['#PSA']
# ['#VoteBlue2018']
# ['#QAnon', '#MAGA']
# ['#Pathetic', '#ConfirmKavanaugh', '#PJNET', '#CCOT', '#maga', '#KAG2018', '#Trump2020', '#NoMoreProgressiveLiberals']
# ['#sorrynotsorry']
# ['#TBT', '#NCDD', '#Conservatives', '#ReviveCivility', '#ToTheVillageSquare']
# ['#Rimmy4Antifa']
# ['#MAGA', '#MAGA']
# ['#MAGA', '#WalkAway', '#ConfirmKavanaugh']
# ['#YESonKavanaugh']
# ['#Manitoba', '#NDP', '#carbontax', '#Trudeau', '#Liberals', '#Winnipeg', '#Canada', '#MBpoli']
# ['#antiFa', '#resist']
# ['#KAG', '#MAGA']
# ['#gunsense']
# ['#nope', '#Foster']
# ['#MAGA']
# ['#MondayMotivation', '#SCOTUSpick', '#Adultery', '#McCain', '#MAGA', '#LiberalismIsAMentalDisorder']
# ['#Liberals', '#NotPlastic']
# ['#DEMOCRACY', '#DumpFord', '#Dictatorship', '#CONservatives', '#Liars', '#Fascists', '#ONpoli', '#TOpoli']
# ['#StopKavanaugh', '#StopTrump', '#SaveSCOTUS']
# ['#metoo', '#metoo']
# ['#MAGA']
# ['#maga']
# ['#MAGA', '#VoteRed2018', '#RedWaveRising2018', '#SaveOurCountry', '#VoteDemsOut']
# ['#LOTWVideo']
# ['#Kavanaugh', '#tcot', '#pjnet', '#maga']
# ['#BetoNotForTexas']
# ['#joebiden', '#biden', '#ukraine', '#maga', '#potus', '#zog']
# ['#51']
# ['#MAGA', '#2A', '#Prolife']
# ['#california', '#MAGA']
# ['#ElectoralReform']
# ['#MAGA', '#KAG', '#WalkAway', '#Witchhunt', '#RedWaveRising', '#VoteRed', '#VoteDemsOut', '#VoteRedToSaveAmerica']
# ['#SusanSarandon']
# ['#PeoplesVote']
# ['#SheIsALiar']
# ['#GoVegan']
# ['#MAGA']
# ['#Antifa', '#SocialistDemocrats']
# ['#LoyalWolf']
# ['#makeithappen']
# ['#Collusion']
# ['#Walkaway', '#Runaway', '#LibsHateAmerica', '#CommiesSuck', '#MAGA', '#KAG']
# ['#NRA']
# ['#LiberalismIsaMentalDisorder', '#DemsAreDangerous', '#WalkAway']
# ['#MAGA']
# ['#UFC228']
# ['#race']
# ['#iphone']
# ['#MAGA']
# ['#Antifa']
# ['#NotHelping']
# ['#FortTrump', '#Poland', '#BoomingEconomy']
# ['#obama', '#WalkAway']
# ['#trump', '#MAGA', '#Syria', '#Israel', '#AlternativeFacts', '#WalkAway', '#WalkAwayFromDemocrats', '#LiberalismIsAMentalDisease', '#NEWS', '#Kavanaugh', '#sugardaddyneeded']
# ['#Brexit']
# ['#VA10']
# ['#MAGA']
# ['#AGTResults', '#AGT']
# ['#ThailandChildren']
# ['#MAGA']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#HadexIncursion']
# ['#MAGA']
# ['#RulesforRadicals']
# ['#resist', '#antifa']
# ['#NRA', '#2A', '#MolonLabe', '#gunsense', '#momsdemand', '#MAGA', '#WednesdayWisdom']
# ['#RedWaveRising2018']
# ['#DeclassifyItAll']
# ['#donaldtrump', '#donaldtrumprallies', '#featured', '#springfield']
# ['#MAGA', '#KAG', '#VoteRed', '#WalkAway']
# ['#MAGA']
# ['#QAnons', '#GreatAwakeningWorldwide', '#JoeBiden', '#MAGA']
# ['#JustSayin', '#FakeOutrage', '#Lies', '#LunaticLeft', '#MAGA']
# ['#NVSen']
# ['#ChristineBlaseyKavanaugh', '#ConfirmKavanaughNow']
# ['#Loomer']
# ['#MAGA']
# ['#Antifa']
# ['#iPledgeToVote', '#MAGA', '#RedtoBlue']
# ['#liberals', '#friendsandfamily', '#ethics', '#cdnpoli']
# ['#Trudeau', '#Liberals', '#cdnpoli']
# ['#cdnpoli']
# ['#Labour', '#Councillor', '#GroomingGangs', '#JeremyCorbyn', '#Britain', '#Muslims', '#Islam', '#Leftists', '#MAGA', '#MEGA', '#MCGA', '#MEGA', '#Patriots', '#Conservatives']
# ['#fanniemae', '#fannieGate', '#ThursdayThoughts', '#Releasethetexts', '#NoRedactions', '#Obamagate', '#ObamaKnew', '#DrainTheDeepState', '#MAGA']
# ['#USConstitution']
# ['#Muted']
# ['#Rimmy4Antifa']
# ['#MAGA']
# ['#TrumpTime']
# ['#wisdomwednesday']
# ['#MAGA']
# ['#MeToo']
# ['#MeToo']
# ['#BATTLEBUS']
# ['#Conservatives', '#Republicans', '#TRAITORS', '#America']
# ['#MAGA']
# ['#VoteHimOut', '#VoteBlue', '#VoteThemOut', '#Blackmail']
# ['#MAGA']
# ['#almostcousins']
# ['#WalkAwayFromDemocratsNow']
# ['#JeffSessions', '#BigTech', '#Google', '#Facebook', '#MAGA']
# ['#Sex', '#War']
# ['#WALKAWAYFROMDEMOCRATS']
# ['#TheResistance', '#Resist', '#BashTheFash', '#Antifa', '#SmashFascism']
# ['#qanda']
# ['#WWG1WGA', '#TheGreatAwakening', '#MAGA', '#GodBlessAmerica', '#GodBlessHumanity']
# ['#TTT']
# ['#dtmag']
# ['#MAGA']
# ['#antifa']
# ['#NoNFLZoneHome', '#QAnon', '#MAGA']
# ['#2A', '#CruzCrew', '#TX', '#Florida', '#VoteRedToSaveTexas', '#VoteRedToSaveFlorida']
# ['#MAGA', '#WeThePeople']
# ['#BritishToryCarCrash', '#ToriesOut']
# ['#Antifa']
# ['#Westminster', '#Tories', '#Brexiteers', '#OutOfTheEU', '#AnnaSourpuss', '#UK', '#Leave', '#NoEUDeal', '#EU', '#FuckEU']
# ['#resisters']
# ['#metoo']
# ['#WalkingAway']
# ['#Occupy', '#BlackLivesMatter', '#BaltimoreRiots', '#Ferguson', '#Antifa']
# ['#MeToo', '#FemFrauds', '#MAGA', '#Maddow', '#MorningJoe', '#WednesdayWisdom']
# ['#bigotry', '#hypocrisy', '#walkaway']
# ['#MAGA']
# ['#PATHETIC', '#LOSER', '#WakeUpAMERICA', '#ElizabethSmart']
# ['#NoSpeakerMcCarthy']
# ['#MAGA']
# ['#WhitePrivilege']
# ['#StopKavanaughNow']
# ['#MAGA']
# ['#cdnpoli', '#tpp', '#nafta']
# ['#MAGA']
# ['#NowWatching']
# ['#schiffhead', '#MAGA']
# ['#sad']
# ['#Mueller', '#DOJ', '#FBI', '#CIA', '#LawEnforcement', '#PoliceState', '#DNC']
# ['#MAGA']
# ['#justice']
# ['#MSM', '#MeToo', '#MAGA', '#KAG2018']
# ['#WalkAwayFromDemocrats', '#WalkAway']
# ['#MAGA']
# ['#FamilyProtection', '#CCW']
# ['#Conservatives']
# ['#HIAC', '#SDLIVE']
# ['#Kavanaugh', '#VoteNoOnKavanaugh']
# ['#MAGA']
# ['#MAGA']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#illegalaliens', '#Constitutional', '#tcot', '#AmericaFirst', '#SanctuaryCities', '#Conservatives', '#law', '#Lawyers', '#thewall', '#Trumpwall', '#Wall']
# ['#Antifa']
# ['#whatareyouthinking']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#onpoli', '#pcpo', '#ondp', '#topoli', '#Toronto', '#TOcouncil']
# ['#CraigKardashian']
# ['#AntiFA']
# ['#Google']
# ['#AntiFa']
# ['#marriedtomedicine']
# ['#MAGA']
# ['#stretchedface']
# ['#MAGA', '#KAG2020', '#TCOT', '#TeaParty', '#PJNET', '#WinBlue2018', '#UniteBlue2018', '#Resist']
# ['#DespicableDemocrats', '#FactsMatter', '#MSMediaLies', '#MAGA', '#Republicans2018', '#Trump2020', '#BigRedWave', '#BluePuddle', '#POTUS', '#USAGuard']
# ['#thescore']
# ['#MSM', '#EOTP']
# ['#t']
# ['#RINO', '#VOTE']
# ['#MAGA', '#KAG2018']
# ['#Westminster', '#Tories', '#police']
# ['#stcshooting']
# ['#Neoliberalism', '#poor', '#middleclass', '#Canada', '#liberal', '#Bernier', '#PPC', '#politics', '#government', '#cdnpoli', '#pnpcbc', '#populist', '#racist', '#racism', '#bigot', '#hw', '#polcan', '#pnpcbc', '#cpc', '#lpc', '#ndp']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#MAGA']
# ['#MAGA']
# ['#dem']
# ['#SaveSCOTUS', '#WhatsAtStake']
# ['#MeToo']
# ['#HumanRights']
# ['#2020MAGA']
# ['#MAGA']
# ['#MAGA']
# ['#MAGA', '#PURGE', '#Buildthewall', '#SundayFunday', '#NEWS', '#FAKENEWS', '#MEDIA', '#business', '#FOXNEWS']
# ['#Maga', '#LionsDen', '#MAGA2KAG']
# ['#MAGA']
# ['#antifa']
# ['#WalkAway', '#Liberals', '#JustinTrudeau']
# ['#Darkseid']
# ['#MAGA']
# ['#TrumpTrain', '#MAGA', '#KAG']
# ['#NCAAonSundays']
# ['#TuesdayThought']
# ['#VoteThemAllOut']
# ['#college', '#MAGA', '#DonaldTrump']
# ['#WWG1WGA', '#MAGA', '#TheRainMakers', '#QAnon', '#QArmy']
# ['#MAGA', '#BlueWave2018']
# ['#MAGA']
# ['#Gun', '#1WorldOnline', '#polloftheday']
# ['#CrazyMaxine']
# ['#WalkAway']
# ['#liberals']
# ['#AStarIsBorn']
# ['#Tories', '#Labour', '#GE2017', '#Conservatives']
# ['#ChristineBlaseyFord', '#MAGA']
# ['#MAGA']
# ['#RushFamily']
# ['#TDS']
# ['#PakNeedsMediaPolicy']
# ['#MAGA']
# ['#Labour', '#SWaGodKing']
# ['#cdnpoli']
# ['#Warriorscoach', '#PACGoldenStateWarriors', '#SteveKerr', '#headcoach']
# ['#MAGA']
# ['#MAGA']
# ['#antifa', '#disarmthem', '#antifagoons']
# ['#VoteRedToSaveAmerica']
# ['#MAGA']
# ['#MAGA']
# ['#maga']
# ['#MAGA', '#PostponeTheVote']
# ['#StopKanavaugh']
# ['#Emmys', '#TheSwamp', '#political', '#colinjost', '#MichaelChe', '#MAGA']
# ['#boycottEmmys', '#maga']
# ['#TruthJustice']
# ['#transparency', '#ReleaseTheDocuments', '#MAGA']
# ['#jiyoonfact']
# ['#Metoo']
# ['#FakeNews', '#MAGA', '#Trump', '#WalkAway']
# ['#omg', '#bobbybrown', '#leolahbrown', '#bet', '#Bobby', '#lies', '#celebnmusic247', '#celebritynews', '#breakingnews', '#news', '#thebobbybrownstory']
# ['#1']
# ['#QAnon', '#MAGA']
# ['#TuesdayThoughts']
# ['#MAGA']
# ['#LivedExperiencedIsEvidence']
# ['#NY18']
# ['#r4today']
# ['#ANTIFA']
# ['#Tories', '#Labour', '#GE2017', '#Conservatives']
# ['#workjams', '#everything', '#buyit']
# ['#beauty']
# ['#MAGA']
# ['#elizabethholmes', '#theranos', '#60minutes', '#CMS']
# ['#Antifa']
# ['#MAGA']
# ['#Leftism']
# ['#dummies']
# ['#MAGA']
# ['#MAGA', '#PJNET', '#TrumpTrain', '#LockHerUp', '#Comey', '#Comygate', '#ComeyShouldBeIndicted']
# ['#MAGA', '#Patriot', '#Qanon', '#WalkAway', '#WWG1WGA', '#GodsArmy', '#TheGreatAwakening', '#JESUSLIVES', '#CatchTheRedWave', '#VoteRed']
# ['#Antifa', '#Merkelkratie', '#Maassen', '#Merkel', '#Seehofer']
# ['#WalkAway']
# ['#LIAR']
# ['#Maryland', '#RedNovember', '#KAG']
# ['#Hillary']
# ['#MAGA']
# ['#QAnon', '#NeverForget', '#MAGA']
# ['#Fact', '#hardball', '#tucker']
# ['#WednesdayWisdom', '#2A']
# ['#MAGA', '#tcot', '#p2']
# ['#RoyMoore']
# ['#conservatives']
# ['#MarioKart', '#MAGA']
# ['#Maga', '#LionsDen', '#MAGA2KAG']
# ['#AskAlly']
# ['#Kavanaugh']
# ['#TuesdayThoughts']
# ['#pugchat']
# ['#Emmys']
# ['#loveforjess']
# ['#MAGA', '#ConfirmKavanaugh', '#VoteRedToSaveAmerica']
# ['#WalkAway']
# ['#GITMO', '#MAGA', '#KAG2020', '#DrainTheDeepState', '#WalkAwayDemocrats2018', '#LiberalismIsAMentalDisease']
# ['#WNBA']
# ['#HangHim']
# ['#c4news']
# ['#FakeNews', '#MAGA', '#Trump', '#RedWave', '#Midterms']
# ['#maga']
# ['#MAGA']
# ['#MAGA2018']
# ['#DregsOfSociety', '#MAGA']
# ['#Antifa']
# ['#meneither']
# ['#Cult45Politburo']
# ['#wiunion', '#wipolitics', '#wiright', '#MAGA', '#NRA', '#democRATs', '#demonicRATs', '#PervertsINC']
# ['#MAGA']
# ['#MAGA', '#QANON', '#TRUMP', '#WWG1WGA', '#QARMY', '#QALERT', '#MAGAFORALLINC', '#TOOLATE']
# ['#TPP', '#cdnpoli']
# ['#BING', '#USA', '#MAGA', '#USA']
# ['#1']
# ['#1950sbornwomen', '#NI', '#1950swomen', '#ToryThieves']
# ['#MAGA']
# ['#BrexitShambles']
# ['#TripleTalaq']
# ['#MAGA']
# ['#MAGA']
# ['#Left', '#LisaPage', '#MuellerInvestigation', '#maga']
# ['#1standLast']
# ['#antifa']
# ['#WillieNelson', '#MAGA', '#TheView', '#Democrats', '#MOG', '#MAGA']
# ['#Republicans']
# ['#WalkAwayMarch']
# ['#MAGA']
# ['#Release', '#WWG1WGA', '#MAGA']
# ['#MAGA']
# ['#KeepTexasRed']
# ['#TermLimits', '#Liberals']
# ['#MAGA']
# ['#ReversePCism', '#KAG']
# ['#MAGA', '#Emmys']
# ['#fluffywolf1218']
# ['#Hypocrisy', '#homophobia', '#RoyMoore', '#Kavanaugh', '#JimJordan', '#MarkFoley', '#BobPackwood', '#ClarenceThomas', '#DonaldTrump']
# ['#8217']
# ['#PeoplesVote', '#Brexit', '#StopBrexitSaveBritain', '#StopBrexit', '#brexitshambles']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#Democrats', '#Conservatives', '#justsaying']
# ['#facebook', '#rosetta', '#memes', '#qanon', '#maga']
# ['#MAGA', '#KAG']
# ['#Despicable']
# ['#qanda']
# ['#TrumpNation', '#TrumpTrain', '#MAGA', '#KAG', '#DrainingTheDeepStateSwamp']
# ['#TrumpDerangementSyndrome']
# ['#MAGA', '#TrumpTrain', '#KeepAmericaGreat2020']
# ['#Pedovore', '#AGSessions', '#PedoGateNews']
# ['#HypocrisyMuch', '#FakeNews', '#Liberals', '#BigStuff']
# ['#restingbitchface']
# ['#Kavanaugh']
# ['#AskAlly']
# ['#MAGA', '#WWG1WGA', '#RedWave2018', '#WalkAway', '#Trump2020', '#QAnon']
# ['#DianeFeinstein', '#ClarenceThomas', '#VoteRed2018', '#KAG', '#ConfirmKavanaugh', '#ConfirmCoachK', '#MAGA']
# ['#PushAwardsMayWards']
# ['#Democrats', '#Conservatives', '#walkaway']
# ['#GOP', '#republicans', '#conservatives', '#kavanaugh']
# ['#AMERICA', '#FIRST']
# ['#MAGA']
# ['#Trump', '#MAGA']
# ['#GotOurPiece']
# ['#MuellersMountain', '#endtheGOP', '#endtheNRA']
# ['#treasonousgoverment']
# ['#MAGA']
# ['#Liberals']
# ['#FakeNewsCNN']
# ['#MAGA']
# ['#Republicans', '#FBR', '#Resistance']
# ['#JusticeClarenceThomas', '#MSM']
# ['#MAGA', '#KAG', '#BeBest', '#ChooseRight', '#walkaway', '#TrumpTrain']
# ['#Matta4Congress', '#SendMcCarthyPacking', '#CAdeservesBetter']
# ['#DickDurbin', '#Chicago']
# ['#Mueller', '#Mueller']
# ['#QAnon', '#WWG1WGA', '#GreatAwakening', '#pain', '#DrainTheSwamp', '#LockThemAllUp', '#MAGA', '#popcorn']
# ['#Mccaskill', '#Kavanaugh', '#ChristineBlaseyFord', '#ThursdayThoughts', '#MAGA']
# ['#LibDemConf']
# ['#maga', '#walkaway']
# ['#MAGA', '#TRUMP2020']
# ['#hypocrite']
# ['#Manifesto', '#LoveLondon', '#ImBackingBoff']
# ['#NeverForget']
# ['#MAGA']
# ['#MAGA']
# ['#AndrewGillum', '#Too', '#Progressive', '#Florida', '#Trump', '#MAGA']
# ['#MondayMorning', '#MondayMotivation', '#MondayMood', '#MondayThoughts', '#Republicans', '#MAGA', '#women', '#Christianity']
# ['#MAGA']
# ['#occupy']
# ['#MAGA']
# ['#Kavanaugh']
# ['#WeThePeople', '#TakeUSABack', '#MAGA', '#AmericaFirst', '#USA', '#MondayMotivation', '#MondayMorning', '#MondayMood', '#ConstitutionDay']
# ['#MAGA']
# ['#2A']
# ['#12']
# ['#ALLINOnLonnieIsntFunny', '#MarchOnFromWalker']
# ['#BLUEWAVE2018']
# ['#Genius']
# ['#micropoetry']
# ['#KavanaughConfirmationHearings']
# ['#DoAsISayNotAsIDo']
# ['#reputationTour', '#PCAs', '#TheConcertTour']
# ['#MAGA']
# ['#MAGA', '#WWG1WGA', '#PatriotsUnited', '#Qanon', '#Qarmy']
# ['#Patriots', '#Deplorables', '#WalkAwayFromDemocrats', '#BackTheBlue', '#RapistDemocrats', '#FraudDemocrats', '#MAGA']
# ['#MAGA']
# ['#IDENTYPOLITICS']
# ['#JesusSaves', '#Connecticut']
# ['#Taxpayers', '#Armed', '#GunControl', '#KamalaHarris']
# ['#MAGA']
# ['#MAGA', '#2A', '#Prolife']
# ['#ergnews', '#antinazigr', '#antifagr', '#antifa', '#Stopthehate', '#GoldenDawn', '#GDtrial', '#JesusChrist', '#JesusSaves', '#JesusIsLord', '#JesusIsGod', '#prayers', '#hope']
# ['#qanda']
# ['#alpolitics']
# ['#FortTrump', '#Poland', '#BoomingEconomy']
# ['#RNC', '#GOP', '#MAGA', '#TuesdayThoughts']
# ['#MAGA', '#Winning']
# ['#MAGA']
# ['#MAGA']
# ['#sinmaduroyo']
# ['#MAGA', '#Democrats']
# ['#aikido', '#kravmaga']
# ['#CDC', '#CDC7words', '#BannedWords', '#Orwell', '#doubleplusgoodspeak', '#MAGA', '#TrumpHasDementia']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#ThanksTrump', '#MAGA', '#refugeesNOTwelcome']
# ['#CreepyJoeBiden', '#JoeDontTouchSoMuch']
# ['#DemocratsAreDangerous']
# ['#meDIAtoo']
# ['#CMALT', '#altc']
# ['#ChristianMorals', '#JC4PMNow', '#POVERTY', '#DisabilityRights']
# ['#brexit', '#ChuckChequers']
# ['#metoo']
# ['#ConstitutionDay']
# ['#antifa', '#antifaAREterrorists']
# ['#meDIAtoo']
# ['#LiberalismCausesMentalRetardation', '#Feminists']
# ['#ANTIFA']
# ['#NetNeutrality']
# ['#Liberals', '#ethics', '#friendsandfamily', '#cdnpoli', '#lpc']
# ['#MAGA', '#KAG']
# ['#FarRight', '#Leader', '#QuoteoftheDay', '#NoTrust', '#NoConfidence', '#CrimeSyndicate', '#mafia', '#ToriesOUT', '#CriminalsinUniform', '#CriminalsOutofNumber10', '#GE2018', '#GTTO']
# ['#AskAlly']
# ['#BlueRipple', '#KatesWall', '#OBAMASPYGATE', '#NoAmnesty', '#NoDACA', '#MAGA']
# ['#MAGA']
# ['#retweet', '#share', '#thankyou', '#love', '#share', '#life', '#money', '#crowdfunding', '#gofundme', '#monsterfunder', '#support', '#donate', '#today']
# ['#MAGA', '#WWG1WGA']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#serenawilliams']
# ['#QAnon']
# ['#QAnon', '#GreatAwakening', '#PatriotsFight', '#WeThePeople', '#UnitedWeStand', '#KAG', '#MAGA', '#WakeUp', '#WalkAway', '#RedOctober']
# ['#TooLiberalForNKY']
# ['#politics', '#MeTooWitchhunt']
# ['#ConfirmKavanaugh', '#MAGA']
# ['#WillieNelson', '#TheView', '#Democrats']
# ['#torylies', '#PeoplesVote', '#StopBrexit']
# ['#liberals', '#Hipster', '#EBT']
# ['#Conservatives', '#vaterans', '#TrumpsAmerica']
# ['#disgusted', '#LeonaAlleslev', '#fuck']
# ['#Hetzjagd']
# ['#DUMMYDONNIEJR', '#EnoughIsEnough', '#LIARINCHIEF']
# ['#MAGA']
# ['#maga']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#DougFord', '#Trump', '#ONpoli']
# ['#MAGA', '#KAG2020', '#QAnon', '#WINNING', '#WWG1WGA']
# ['#MAGA']
# ['#MAGA']
# ['#3']
# ['#MorningJoe']
# ['#Liberals']
# ['#ShareTheLove']
# ['#MAGA']
# ['#FortTrump', '#Poland', '#BoomingEconomy']
# ['#Walkaway']
# ['#TeamDanny']
# ['#Democrats', '#WalkAway', '#TrumpTariffs', '#TrumpTrain', '#MAGA']
# ['#drellenbrandt', '#MAGA']
# ['#Tories', '#Labour', '#GE2017', '#Conservatives']
# ['#Liberals']
# ['#NotOneMore', '#GunControlNow']
# ['#KillTheZebras']
# ['#MAGA']
# ['#MAGA']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#Tories']
# ['#ChristinaBlaseyFord', '#tcot', '#p2']
# ['#Congress', '#keithellison', '#StopTheBias', '#WalkAwayDemocrats2018', '#RedWave2018', '#MAGA']
# ['#Levis', '#NeverAgain', '#GunSenseNow']
# ['#MAGA', '#NoCollusion']
# ['#Theresa', '#LabourParty', '#Government', '#HousingCrisis', '#housingmarket', '#conservatives', '#Landowners', '#ToriesOut', '#Corruption']
# ['#MAGA', '#WallDoesntProtectFromAmericans']
# ['#A8']
# ['#Evil', '#Greedy', '#Hateful', '#Pigs', '#Education', '#MAGA', '#BetsyDeVos']
# ['#Mifsud']
# ['#MAGA']
# ['#Biden', '#POTUS']
# ['#Tory', '#GE2010', '#1950sbornwomen', '#onevoice']
# ['#Maga', '#LionsDen', '#MAGA2KAG']
# ['#LockHerUp', '#MAGA']
# ['#Antifa']
# ['#MAGA', '#wwg1wga', '#KAG', '#LiberalismIsAMentalDisorder']
# ['#TuesdayThoughts']
# ['#MAGA', '#KAG', '#California', '#FakeUberDriver', '#BodyWrapRestraint', '#CrimeNews']
# ['#GreatAwakening', '#QAnon', '#followthewhiterabbit', '#MAGA']
# ['#PresidentMaduro', '#SaltBae', '#Venezuelans', '#Starvation', '#socialist', '#BBC', '#SKY', '#LBC', '#Labour', '#LabourParty', '#JeremyCorbyn', '#USA', '#Venezuela']
# ['#FoxNews']
# ['#EnglishConservatism']
# ['#Antifa', '#WA', '#POLICE', '#Police', '#Combat', '#ThinBlueLine', '#MAGA', '#KAG', '#BlueLivesMatter', '#LawEnforcement', '#2A']
# ['#AdamandEve']
# ['#parklandkids', '#neveragain']
# ['#VictoriaSecrets', '#KAG']
# ['#Conservatives', '#frustrated', '#Congress', '#tcot']
# ['#WillieNelson']
# ['#Tories', '#Labour', '#GE2017', '#Conservatives']
# ['#firemalyoung']
# ['#PeoplesVote', '#StopBrexit', '#remain']
# ['#DoYourJob', '#DoTheRightThing', '#SCOTUS', '#JudgeKavanaugh', '#MAGA', '#KAG', '#ConfirmKavanaughNow', '#MAGA', '#KAG']
# ['#GreatestThingsAboutThe90s']
# ['#POTUS45', '#Mavericks', '#MarkCuban', '#metoo', '#maga']
# ['#canpoli']
# ['#BoycottColinJost', '#EmmyAwards']
# ['#Freakingliars']
# ['#Louis']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#loveit']
# ['#Professor', '#AR']
# ['#StaffPick']
# ['#LIVPSG']
# ['#Trump45', '#MAGA2KAG']
# ['#NFL', '#GiveKapAChance', '#ImWithKap']
# ['#180']
# ['#Trump2020', '#TRUMP2020', '#MAGA']
# ['#metoo', '#resistance', '#blm', '#antifa', '#Kaepernick']
# ['#MAGA']
# ['#MAGA', '#TuesdayThoughts']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#WalkAway']
# ['#MAGA']
# ['#WWG1WGA', '#MAGA', '#TheRainMakers', '#QAnon', '#QArmy']
# ['#PlannedParenthood', '#USGoverment', '#Abortion', '#Slavery', '#Savethe8th', '#prolife', '#ccot', '#RedNationRising', '#teaparty', '#conservatives', '#MAGA', '#repealthe8th', '#teaparty', '#PJNET']
# ['#WalkAwayDemocrats']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#ShariaLaw', '#ConstitutionDay', '#MAGA', '#MondayMorning']
# ['#NetherlandsTaxHaven']
# ['#CultLogic', '#MAGA']
# ['#ILLEGALALIEN', '#405', '#California', '#losangeles', '#Kavanaugh', '#MAGA']
# ['#cnn', '#sitroom', '#TheLead', '#outfront', '#AC360', '#NPR', '#PBSnews', '#PBSnewshour', '#tcot', '#tlot', '#maga', '#sgp', '#nyc', '#boston', '#baltimore', '#cleveland', '#chicago', '#milwaukee', '#denver', '#stlouis', '#houston', '#dallas', '#atlanta', '#la']
# ['#ConstitutionDay', '#MAGA', '#QAnon']
# ['#WalkedAway']
# ['#Liberals', '#MAGA']
# ['#CINO']
# ['#PeoplesVote']
# ['#MCCASKILL', '#MAGA', '#Kavanaugh', '#ChristinaBlaseyFord', '#QANON', '#ThursdayMotivation']
# ['#Republican', '#Democrats']
# ['#Tories', '#Labour', '#GE2017', '#Conservatives', '#proudtobeaconservativefromacouncilestate']
# ['#chatterbox']
# ['#Antifa']
# ['#Hillary', '#Trump', '#Clinton', '#Trump', '#conservatives', '#TCOT', '#Unmasking', '#ReleaseTheMemo', '#SusanRice', '#FBI', '#DeepState', '#Mueller']
# ['#MAGA', '#MAGA']
# ['#LiberalismIsAMentalDisorder', '#MAGA']
# ['#RoxhamRoad']
# ['#BoycottNFL']
# ['#LoveOurPOTUS', '#MAGA', '#KAG']
# ['#TrumpNation', '#MAGA', '#China']
# ['#LikeNoOther', '#GameStopContest']
# ['#MAGA']
# ['#MAGA', '#WWG1WGA', '#RedWave2018', '#DrainTheSwamp', '#FortTrump']
# ['#WelfareForAll', '#Iatrogenesis']
# ['#MAGA']
# ['#MAGA', '#KAG']
# ['#MAGA', '#DrainTheSwamp', '#TermLimits', '#DitchMitch', '#PeelPelosi']
# ['#Partybeforecountry', '#massmedia']
# ['#MAGA', '#TheGreatAwakening', '#QAnon', '#YouAreGoingToJail', '#YouHaveBeenExposed']
# ['#CA23', '#dosomething', '#votethemout', '#voteBlue2018']
# ['#TEDCRUZ', '#MAGA']
# ['#AskAlly']
# ['#antifa']
# ['#LeviStrauss', '#GunControl', '#CBS', '#SanFrancisco', '#NoMoreLevis', '#guns', '#NRA', '#USA', '#GOP', '#libertarian', '#conservative']
# ['#kanebrown', '#WeStandTogether', '#maga']
# ['#2A']
# ['#realDonaldTrump']
# ['#maga']
# ['#JulieBurchill', '#brexit']
# ['#Kavanaugh']
# ['#PuertoRicans', '#HurricaneMaria', '#ThursdayThoughts', '#ThursdayMotivation', '#resistance', '#resist', '#MAGA', '#Military', '#veterans', '#TCOT', '#ThisIsAmerica']
# ['#KAG', '#MAGA']
# ['#SJW', '#Liberals']
# ['#LoonyLeft']
# ['#walkaway']
# ['#ImWithDave', '#LBC']
# ['#good']
# ['#MAGA', '#Cult45']
# ['#maga']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#tch']
# ['#CurrentAffairs']
# ['#voteredNovember2018']
# ['#EverybodyTalks']
# ['#PostponeTheVote', '#maga', '#ncpol']
# ['#EndPC', '#Portland', '#abortion', '#GunControl', '#EndCulturalMarxism']
# ['#WWG1WGA', '#QAnon', '#QArmy', '#MAGA', '#TheGreatAwakening']
# ['#MorningJoe']
# ['#ExposeTheTruth', '#CCOT']
# ['#PJNET', '#MAGA', '#TrumpTrain', '#TrumpTrain2020', '#corybooker', '#MAGA', '#KAG', '#KeepAmericaGreat', '#PresidentTrump']
# ['#antifa']
# ['#MAGA']
# ['#NJ12', '#MAGA', '#WalkAway']
# ['#NeverTrump', '#MAGA']
# ['#MAGA']
# ['#narcissism']
# ['#Kavanaugh', '#MAGA', '#MakeAmericaGreatAgain', '#TheResistance']
# ['#GroupThinkStinks']
# ['#MAGA', '#WWG1WGA']
# ['#MAGA']
# ['#Liberals']
# ['#MAGA', '#ConfirmKavanaugh', '#DemsDesperate']
# ['#HAPPYHYUNJAEDAY', '#BELIEVE_HYUNJAE_DAY', '#너의존재가_기적이야']
# ['#OneTROY', '#GoTrojans', '#ProudAlum']
# ['#MAGA']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#Resistance', '#Drumpf']
# ['#UofGH']
# ['#MAGA']
# ['#WeMakeAmericaGreat']
# ['#MAGA', '#KAG']
# ['#TakeAStandNotAKnee']
# ['#libtards', '#walkaway', '#maga']
# ['#ProteccKaiser']
# ['#LickAWitch']
# ['#resist', '#Antifa']
# ['#BuildTheWall']
# ['#MAGA']
# ['#10millionsubscribers']
# ['#MAGA', '#WWG1WGA']
# ['#MAGA']
# ['#TalkLikeAPirateDay', '#1950swomen', '#1950sbornwomen', '#backto60', '#onevoice']
# ['#traitor', '#VoteHimOut']
# ['#Yemen']
# ['#NickiDaGOAT']
# ['#IBelieveChristine', '#Kavanaugh', '#womenarewatching', '#VoteThemOut']
# ['#maga']
# ['#wwg1wga', '#qanon', '#MAGA', '#walkaway']
# ['#Kavenaugh', '#ThursdayThoughts', '#FridayFeeling', '#DemDirtyTrick', '#MAGA', '#Resist']
# ['#MAGA']
# ['#AltRight']
# ['#MAGA', '#KAG', '#RedWaveRising', '#ConfirmKavanaugh', '#WalkAway', '#follo4follo', '#TrumpTrain']
# ['#antifa']
# ['#deepstate', '#MAGA', '#RedWaveRising', '#redwave', '#WalkAwayFromDemocrats', '#WalkAway', '#WalkAwayMarch']
# ['#MAGA', '#KAG', '#DeepState']
# ['#VoteBlue']
# ['#qanon']
# ['#MAGA']
# ['#ConfirmKavanaugh', '#MAGA', '#ChristineBlaseyFord']
# ['#MAGA']
# ['#Antifa']
# ['#sitroom', '#TheLead', '#outfront', '#AC360', '#NPR', '#PBSnews', '#PBSnewshour', '#tcot', '#tlot', '#maga', '#nyc', '#boston', '#baltimore', '#cleveland', '#chicago', '#milwaukee', '#denver', '#philadelphia', '#la']
# ['#BernierNation']
# ['#MAGA2KAG', '#WINNING']
# ['#GE2018']
# ['#antifa', '#socialism']
# ['#GunControlNow', '#VoteBlue']
# ['#nyfw']
# ['#MarkJudge', '#Kavanaugh', '#MAGA', '#KAG', '#AmericaFirst', '#Trump', '#FoxReport']
# ['#ICYMI', '#Kavanaugh', '#KavaNOPE']
# ['#qanon', '#WWG1WGA', '#MAGA', '#MBGA']
# ['#KARRIGAN']
# ['#Florida']
# ['#VoteRepublican', '#ARM', '#AmericanRedMidterms', '#Conservatives', '#Independents', '#Undecided', '#WalkAway', '#LJMAGA', '#GoRedStateByState']
# ['#Tories', '#Labour', '#GE2017', '#Conservatives']
# ['#WakeUpStandUpSpeakUp']
# ['#VoteRedToSaveAmerica']
# ['#maga']
# ['#MadMaxineWaters', '#WakeUpAmerica']
# ['#tree', '#greets', '#BLUE', '#Up', '#BardBits']
# ['#Trump', '#democrats', '#liberals', '#neveragain', '#Resist', '#ImpeachTrump', '#MuellerTime']
# ['#PeopleOverProfits']
# ['#MakeAmericaGreatAgain', '#MAGA', '#USA']
# ['#NeverTrump', '#AntiFA']
# ['#ProjectReality', '#ExitFromBrexit', '#endthechaos', '#StopBrexit', '#finalsay', '#PeoplesVote']
# ['#MAGA']
# ['#Liberals', '#California', '#Radicals']
# ['#MAGA']
# ['#cancelsouthpark']
# ['#straightfire', '#hiac']
# ['#JoeBiden', '#DregsOfSociety', '#Antifa', '#CrazyUncleJoe']
# ['#InstitutionalRacism']
# ['#Liberal', '#activist', '#banning', '#MEN']
# ['#Brexit']
# ['#WWG1WGA']
# ['#MAGA']
# ['#MAGA', '#NEWS', '#NikeBoycott', '#ColinKaepernick', '#nflfootball', '#NFL', '#TrumpResign', '#CNN']
# ['#BuildTheWall', '#RedNationRising', '#Trump', '#MAGA', '#SendThemHome']
# ['#MAGA']
# ['#auspol']
# ['#HasBeen']
# ['#ScruffBag']
# ['#TheresaMay', '#whiteprivilege', '#homeless', '#Muslims', '#Corbyn', '#MAGA', '#MBGA', '#MCGA', '#MEGA', '#Conservatives', '#Patriots']
# ['#RedWaveRising', '#MAGA', '#KAG2018']
# ['#Qanon', '#WWG1WGA']
# ['#USA', '#liberals', '#Libya', '#Iraqi']
# ['#MAGA', '#KAG', '#DeepState', '#WalkAway', '#RedWave2018']
# ['#Soros']
# ['#PresidentTrump', '#CA', '#GunControl', '#GOA', '#NRA', '#GunRights', '#SelfDefense', '#A2', '#firearms', '#MolonLabe', '#guns', '#KAG', '#SecondAmendment', '#CCOT', '#PJNet', '#GunFreeZones', '#MAGA', '#USConstitution']
# ['#BoycottTheNFL', '#BoycottNike', '#JustDont']
# ['#MAGA']
# ['#NFL', '#QAnon', '#MAGA', '#WWG1WGA', '#FreeAlexJones']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#USA', '#Trump', '#MAGA', '#KAG', '#China', '#Russia', '#Hollywood', '#Soros', '#SaudiArabia', '#TheCatholics', '#liberal', '#democrat', '#conservatives']
# ['#DrainTheDeepState', '#DrainTheDeepStateSwamp', '#maga']
# ['#MAGA']
# ['#MAGA', '#WalkAway', '#IamAlexJones', '#Kavanaugh', '#PPC']
# ['#Liberals', '#BREAKING', '#MAGA', '#PatriotsUnited', '#AmericaFirst']
# ['#Nikes']
# ['#Emmys']
# ['#TheWallStreetJournal', '#WallStreetJournal']
# ['#DeplorableDreg', '#TrumpsArmy', '#TeamTrump', '#WWG1WGA', '#MAGA', '#KAG']
# ['#MAGA']
# ['#pnpcbc', '#cdnpoli', '#bcpoli', '#ontpoli', '#alpoli', '#Conservatives']
# ['#SalzburgSummit18']
# ['#Elections', '#News', '#HeadlineNews']
# ['#maga']
# ['#SesameStreet', '#Bert', '#Ernie', '#closet', '#couple', '#Conservatives', '#Nike', '#Gay', '#lgbtq', '#lgbtqtwitter', '#bluewave']
# ['#Cult45']
# ['#MAGA', '#ConfirmKavanaugh', '#JUSTICENOW', '#VoteRedToSaveAmerica', '#GodBlessAmerica', '#AnnaLovesTrump', '#TrumpsArmy']
# ['#ONpoli']
# ['#MAGA', '#Kavanaugh', '#KavanaughConfirmation', '#KavanaughConfirmationHearings']
# ['#MAGA']
# ['#MAGA']
# ['#JohnMcCain', '#weasel']
# ['#MAGA', '#DrainTheSwamp']
# ['#alpolitics']
# ['#WalkAway', '#MAGA']
# ['#Kavenaughs']
# ['#DNCwbore', '#LyingSkank', '#KavanaughConfirmation', '#ChristineBlaseyFord', '#RedNationRising', '#KAG', '#MAGA', '#CCOT']
# ['#LockHerUp']
# ['#cdnpoli']
# ['#AlwaysACowboy', '#NFLSunday', '#CowboysNation', '#DEZBRYANT', '#88']
# ['#MAGA']
# ['#TuesdayThoughts']
# ['#AVFC', '#BRUCEOUT']
# ['#WebberForCongress', '#NJ11', '#MAGA', '#Liberals', '#Impeach', '#POTUS', '#Trump']
# ['#FarRight', '#Psychopath', '#Leader', '#invisible', '#press', '#created', '#catkiller', '#excuse', '#FoxHunting', '#Christmas', '#AnimalCruelty', '#ToriesOUT', '#NoConfidence', '#CrimeSyndicate', '#GE2018', '#CriminalsOutofNumber10']
# ['#Police', '#UnitedKingdom']
# ['#BuildTheWall', '#LockThemUp', '#DrainTheDeepState', '#NFLWalkAway', '#MAGA']
# ['#WalkAway', '#CommunismKills', '#LuciferiaRising', '#MAGA', '#Trump2020']
# ['#MeTooMovement', '#Trump', '#MAGA', '#KavanaughConfirmationHearings']
# ['#8217']
# ['#LeviStrauss', '#LEVISTRAUSS', '#SanFrancisco', '#America']
# ['#MAGA']
# ['#DonJr', '#DonaldTrumpJr', '#WednesdayWisdom', '#TheResistance', '#MAGA', '#Trump', '#FoxNews', '#Resist', '#ImpeachTrump']
# ['#MAGA', '#QANON', '#TRUMP', '#WWG1WGA', '#QARMY', '#QALERT', '#MAGAFORALLINC', '#TEAMTRUMP']
# ['#rockthe36', '#VoteDayna']
# ['#maga']
# ['#Antifa']
# ['#METOO']
# ['#GoodRead', '#2A']
# ['#Maga']
# ['#Intellectualidiot']
# ['#EmmyAwards']
# ['#FalseFlags', '#Propaganda', '#Palestine', '#NWO', '#ChosenPeople']
# ['#maga', '#MEGA']
# ['#SWIFTgpi', '#payments', '#BFNewYork']
# ['#maga']
# ['#LindaSarsour', '#FakeFeminist', '#ShariaLaw', '#AntiSemetic', '#Liberals', '#Palestinian', '#AntiSemetic', '#AntiAmerican', '#PcLiberal', '#WakeUP']
# ['#MAGA']
# ['#MAGA', '#MakeAmericaGreatAgain']
# ['#brexit', '#remain', '#fiftiesbornwomen', '#ShoulderToShoulder', '#onevoice', '#WePaidInYouPayOut', '#waspi', '#StatePensionage', '#labour', '#libdem', '#conservatives', '#rectify']
# ['#POTUS', '#MAGA', '#Emergency', '#QAnon', '#MondayMotivation', '#ConstitutionDay']
# ['#artistforhire', '#commission', '#robots', '#anthro', '#furry', '#monstergirls', '#cyclops', '#pokemon', '#magikarp', '#catgirls', '#possum', '#artistsontwitter']
# ['#MAGA']
# ['#trump', '#maga', '#art', '#comicart']
# ['#KavanaughConfirmation', '#KavanaughWithdraw', '#KavanaughSCOTUS', '#maga']
# ['#BoycottNike']
# ['#FM19']
# ['#IJustDontSeeMyself', '#2A', '#Liberals4Guns', '#guns', '#SecondAmendment']
# ['#literalviolence']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#MAGA']
# ['#liberalfool']
# ['#draintheswamp']
# ['#YouHaveBeenExposed', '#TheGreatAwakening', '#DrainTheSwamp', '#YouAreGoingToJail', '#MAGA', '#QAnon']
# ['#Causality', '#guncontrol', '#COHORT']
# ['#qanon', '#qarmytrain', '#wwg1wga', '#DrainTheDeepState', '#MAGA']
# ['#WomenShouldRuleTheWorld']
# ['#ticats']
# ['#Brilliant']
# ['#MSM', '#KeithEllison']
# ['#JusticeForOliver']
# ['#MAGA', '#Qanon', '#WWG1WGA', '#Trump', '#TrustThePlan']
# ['#MAGA']
# ['#RHONY']
# ['#TuesdayTips', '#MAGA', '#KAG']
# ['#JFKJR', '#JFKJr']
# ['#PremiosHeat2018', '#LatinGRAMMYCNCO', '#CNCOnEllen', '#CNCO', '#TheLatinArtist', '#PCAs', '#followERickOnIG']
# ['#NothingLower']
# ['#Antifa', '#MeToo', '#Hypocrites', '#LiberalismIsAMentalDisease']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#transparency']
# ['#MAGA', '#KAG']
# ['#NickFerrari', '#Muslims', '#LBC', '#LBCRadio', '#MAGA', '#MCGA', '#MEGA', '#MBGA', '#Conservatives', '#Patriots']
# ['#Tyranny', '#Totalitarianism', '#Leftism', '#THELEFT', '#Liberals']
# ['#WWG1WGA']
# ['#cancel']
# ['#lowemissions', '#bus', '#transport', '#Conservatives']
# ['#MAGA', '#TheResistance', '#MondayMotivation']
# ['#maga']
# ['#TwitterShouldBe']
# ['#MAGA']
# ['#MAGA']
# ['#ConfirmKavanaugh']
# ['#ConstitutionDay', '#TRUMP', '#MAGA', '#TRUMPTRAIN', '#LIBERTY', '#FREEDOM', '#AMERICA', '#USA', '#LIBERTY']
# ['#AskAlly']
# ['#followed']
# ['#antifa']
# ['#VoteRonDeSantis2018']
# ['#MAGA']
# ['#trump', '#trump2020', '#maga', '#maga2020', '#trumpbabes', '#trumpbabes2020', '#trump_babes_2020', '#milfsfortrump', '#babesfortrump', '#babesfortrump2020']
# ['#CONservatives', '#cdnpoli']
# ['#Trump2020', '#keepitpublic']
# ['#MAGA', '#KAG']
# ['#MAGA']
# ['#MAGA']
# ['#FakeNews', '#MAGA', '#WalkAway']
# ['#MAGA']
# ['#StopKavanaughNow']
# ['#maga']
# ['#MAGA', '#2ADefenders', '#TrumpTime']
# ['#Spanish', '#unjustice', '#FreedomOfExpression', '#HumanRights', '#Spain', '#fakedemocracy', '#cddr', '#shameonSpain']
# ['#MAGA']
# ['#POTUS', '#Trump', '#MAGA', '#KAG', '#NEWS']
# ['#MeToo', '#Resist', '#Antifa']
# ['#trumpisamoron', '#Stopkavanaugh', '#NYTimesOpEdByQaNon']
# ['#Liberals', '#Canada']
# ['#Liberals', '#Conservatives']
# ['#2A']
# ['#MAGA', '#Trump', '#USA']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#ExpectUs', '#GunSenseCandidates', '#GOTV', '#ThrowThemOut']
# ['#Tories', '#Labour', '#GE2017', '#Conservatives']
# ['#maga', '#kag', '#trump']
# ['#MAGA']
# ['#TrumpTrain2020', '#Democrat', '#RoeVWade', '#BuildTheWall', '#MAGA']
# ['#supplymanagement']
# ['#Ridiculous']
# ['#PatriotsUnite', '#PatriotsFight', '#WWG1WGA', '#GrowTheNetwork', '#MakeAmericaGreatAgain', '#KeepAmericaGreat', '#TheGreatAwakening', '#TheStormIsUponUs', '#TheEyeOfTheStorm', '#MAGA', '#KAG', '#ILoveAmerica']
# ['#DearProfessorFord']
# ['#MeToo']
# ['#MAGA']
# ['#GET', '#conservatives', '#MAGA']
# ['#DrainTheSwamp', '#BREAKING', '#FISADocs', '#Declassified', '#DeepStateCorruption', '#politics', '#MAGA']
# ['#wwe', '#HIAC']
# ['#Deplorables', '#MAGA']
# ['#thankyou']
# ['#WeThePeople']
# ['#MAGA', '#TrumpLies']
# ['#VoteRed', '#MAGA']
# ['#MAGA']
# ['#StopTheBias']
# ['#BearDown', '#hunting']
# ['#SadiqKhan', '#children', '#WarZones', '#London', '#Mayor', '#MayorOfLondon', '#MAGA', '#MBGA', '#MEGA', '#MCGA', '#Conservatives', '#Patriots']
# ['#gunsense']
# ['#MAGA', '#WalkAway', '#RedTsunami']
# ['#sickkidsinlove']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#Q', '#QAnon', '#QArmy', '#MAGA', '#WeThePeople', '#followthewhiterabbit', '#WWG1WGA', '#SpyGate', '#RedWaveRising', '#EnoughIsEnough', '#WalkAway', '#propaganda']
# ['#MAGA']
# ['#NRA', '#maga']
# ['#Russiacollusion', '#LiberalismIsAMentalDisorder', '#FISAGate', '#Deepstateisreal']
# ['#MAGA', '#WWG1WGA']
# ['#MichaelChe']
# ['#ImWithSnoop']
# ['#Conservatives', '#frustrated', '#Congress', '#tcot']
# ['#LeviStrauss', '#CEO']
# ['#cognitivedissonance']
# ['#MRU', '#CdnPoli']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#Antifa', '#DeepStatePanic']
# ['#Nike']
# ['#BlueWaveofViolence']
# ['#antifa']
# ['#RIPM']
# ['#RSSReachesOut']
# ['#Hollywood', '#Satanists', '#Pedo', '#Jesus', '#Conservatives']
# ['#WhyRWPreachesRacism', '#RWLuciferianCult']
# ['#Q', '#QAnon', '#MAGA', '#QArmy', '#WWG1WGA']
# ['#JudgeKavanaugh', '#ZipIt']
# ['#metoo']
# ['#BetoforSenate']
# ['#Reylo']
# ['#CCOT', '#MAGA', '#WalkAway', '#VoteDemsOut2018', '#TrumpsArmy']
# ['#MAGA', '#MSAGA']
# ['#british', '#brexit', '#may', '#BorisJohnson', '#brexiteers', '#corbyn', '#chequers', '#conservatives', '#fbpe', '#PeoplesVote']
# ['#MAGA']
# ['#Topbuzz']
# ['#LPFirstTime']
# ['#GunControl', '#BulletControl']
# ['#MAGA', '#2A', '#Prolife']
# ['#guns', '#2A']
# ['#FoxNews', '#SocialismSucks']
# ['#MAGA']
# ['#MAGA', '#AmericaFirst']
# ['#PSYC1101']
# ['#MAGA', '#ConfirmKavanaughNow', '#POTUS']
# ['#marketing', '#sales', '#retail', '#style', '#WednesdayWisdom']
# ['#ConstitutionDay', '#MAGA', '#KAG', '#Obama', '#Clinton', '#DeepState', '#Spygate', '#WitchHunt', '#Sedition', '#TREASON']
# ['#KUFball']
# ['#wwg1wga', '#qanon', '#MAGA', '#walkaway']
# ['#GunSense', '#GunControlNow', '#GunControl']
# ['#ChristineBlaseyFord', '#KavanaughConfirmationHearing', '#TheHandmaidsTale', '#MAGA']
# ['#MAGA', '#WalkAway']
# ['#ConspiracyNoMore', '#PatriotsWin', '#TrumpTreason', '#TheTruthShallSetUsFree', '#MAGA', '#WWG1WGA']
# ['#Hollyweeders']
# ['#NowReading']
# ['#Nottowatch']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#DeathPenalty', '#Treason', '#Pedogate', '#MAGA', '#QAnon']
# ['#Kavanaugh', '#KavanaughConfirmation', '#metoo']
# ['#BarbieDreamsVIDEO']
# ['#messedup']
# ['#LyingLiberals', '#HurricaneMaria', '#Poverty']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#TroughTime']
# ['#entrepreneur', '#smb']
# ['#Kavanaugh']
# ['#Beto']
# ['#MarchforOurLives']
# ['#ANTIFA']
# ['#NeverTrump', '#MAGA']
# ['#MAGA']
# ['#askalivelshi']
# ['#JIMIN', '#BTS', '#MAIN']
# ['#trump', '#maga']
# ['#cdnpoli']
# ['#MondayMotivation', '#Deplorables', '#MAGA', '#MarinesagainstTrump', '#KavaNO', '#BlueWave2018', '#PostponeTheVote', '#Kavanaugh', '#StopKavanaugh']
# ['#Westminster', '#Tories', '#Brexit', '#Brexiteers', '#OutOfTheEU', '#EU', '#Brussels', '#Remoaners', '#Remainers', '#Quislings', '#FBPE', '#Non', '#Anti', '#Pro', '#Traitors', '#snowflakes', '#bedwetters', '#LeftieLuvvieLiberals']
# ['#MAGA', '#QAnon', '#ThursdayThoughts', '#DrainTheDeepState', '#ThankfulThursday', '#WWG1WGA', '#WalkAway']
# ['#MAGA']
# ['#Resister', '#MAGA', '#Trump2020']
# ['#makotoniijimaweek2018']
# ['#TheEmmys']
# ['#IdiotAlert']
# ['#GOPHypocrites']
# ['#VoteDemsOut', '#MAGA', '#2020', '#ConfirmJudgeKavanaugh']
# ['#KillGough', '#auspol']
# ['#TRUMPARMY', '#AllVetsRadio', '#VOC', '#TheBrooksBrown', '#MAGA']
# ['#TrumpDerangementSyndrome', '#liberals', '#msm']
# ['#cincinatti']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#DeutscheBank', '#Mueller', '#Kavanaugh']
# ['#LDConf2018', '#DemandBetter']
# ['#MAGA', '#WalkAway']
# ['#Muslims', '#Islam', '#WhiteSupremacist', '#Terrorists', '#Ramsgate', '#MAGA', '#MEGA', '#MCGA', '#MBGA', '#Conservatives', '#Patriots']
# ['#NancyPelosi', '#chuckschumer']
# ['#brexit']
# ['#RedWaveRising']
# ['#102']
# ['#VoteRedToSaveAmerica', '#MAGA']
# ['#diversity', '#tribalism', '#culturalappropriation', '#America', '#tcot', '#conservatives']
# ['#cdnpoli']
# ['#doSomthing', '#VoteTheGOPOut', '#CountryOverParty']
# ['#antifa']
# ['#teamtani']
# ['#Ethiopia']
# ['#Toad', '#MAGA', '#Trump2020']
# ['#MAGA', '#2A', '#rahmemanuel', '#ChicagoPD']
# ['#WalkAwayFromDemocrats', '#VoteRedToSaveAmerica', '#VoteRed2018', '#MCGA', '#MAGA']
# ['#Chicago', '#nuclearfamily', '#twill']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#KAG', '#MAGA', '#KavanaughAccuser']
# ['#SlimShady', '#TheGreatAwakening', '#Qanon', '#MAGA', '#TheStorm', '#WWG1WGA', '#JesusIsBack', '#GodIsGreat']
# ['#Dems']
# ['#MAGA']
# ['#Fake', '#Novichok']
# ['#MAGA', '#WWG1WGA', '#DrainTheSwamp', '#QAnons', '#DOWN_WITH_GOVERNMENT_CORRRUPTION']
# ['#OUTFRICKINGSTANDING', '#MAGA2020']
# ['#Antifa', '#resist']
# ['#Putin', '#MAGA']
# ['#2A']
# ['#PUBLIC_EXECUTIONS', '#MAGA', '#WWG1WGA', '#QAnon', '#DrainTheSwamp', '#DrainTheDeepState']
# ['#Tana']
# ['#MAGA']
# ['#AnitaHill', '#Conservatives']
# ['#Anonymous']
# ['#TermLimits']
# ['#MAGA', '#2A', '#Prolife']
# ['#onpoli']
# ['#labour', '#conservatives', '#bbcqt', '#brexit', '#eu']
# ['#Leave', '#EU', '#ChuckMay', '#ChuckChequers', '#BoJo4PM']
# ['#18n18']
# ['#BB20']
# ['#FreedomOfExpression', '#FreedomOfExpression']
# ['#MAGA']
# ['#mdzs2018']
# ['#BigBossTamil']
# ['#MAGA']
# ['#america', '#usa', '#VoteBlueAndBringAFriend']
# ['#MAGA']
# ['#WeMarchForOurLives', '#EnoughIsEnough', '#DNC', '#GOP', '#empowerment']
# ['#MEME', '#Chinese', '#chinesespy', '#California', '#WeThePeople', '#DrainTheSwamp', '#Justice', '#ClintonEmails', '#MAGA', '#WWG1WGA', '#CaliforniaWildfires', '#RedPill', '#FactsMatter', '#FactsOnly', '#MakeCaliforniaGreatAgain', '#kag', '#DNC', '#LiberalLogic', '#Truth', '#MSM', '#facts']
# ['#TuesdayThoughts']
# ['#MAGA', '#Trump2020']
# ['#listentoindustry']
# ['#DrainTheSwamp']
# ['#StopKavanaugh', '#TCOT', '#MAGA', '#RedNationRising']
# ['#maga', '#MakeAmericaGreatAgain', '#makeamericaamericaagain', '#makeamericastrongagain', '#makeamericasafeagain', '#makeamericasaneagain']
# ['#MAGA', '#KAG']
# ['#DemocratsDividingAndDestroyingAmerica', '#DemocratsHateAmerica']
# ['#peoplesvote']
# ['#TBT']
# ['#roeselare', '#conservatives']
# ['#DemocratsHateAmerica', '#Democrats', '#Antifa']
# ['#maga', '#KAG']
# ['#MAGA']
# ['#MAGA', '#LICENSEREPORTERS']
# ['#MAGA']
# ['#MAGA']
# ['#hypocrite']
# ['#conservativesattackondemocracy', '#canada', '#theCPCisapoliticalhategroup']
# ['#MAGA']
# ['#WalkAway', '#AmericaFirst', '#MAGA']
# ['#Conservatives', '#DirtyPolitics']
# ['#Kavanaugh', '#MAGA']
# ['#stitchup']
# ['#MAGA', '#KAG']
# ['#PushAwardsMayWards']
# ['#UKIP', '#Scotland', '#Coburn', '#May', '#Brexit', '#Conservatives']
# ['#ConservativeComedy']
# ['#maga']
# ['#MAGA', '#TRUMP2020']
# ['#MAGA']
# ['#politicslive']
# ['#MAGA']
# ['#alpolitics']
# ['#YouFailed', '#Trump2020', '#MAGA', '#MakeAmericanGreatAgain', '#OpportunityKnocks']
# ['#politicsLive', '#JustAThought']
# ['#osho', '#quotes']
# ['#Westminster', '#HouseOfLords', '#Tories', '#Brexit', '#LabourParty', '#Labour', '#hypocrites', '#ShowerOfShite']
# ['#BrexitBritain']
# ['#Republicans', '#Conservatives', '#Independents', '#Hillarites', '#Democrats', '#History', '#ConfirmKavanaugh']
# ['#UnsealTheDeals', '#Congress', '#SlushFunds', '#MAGA', '#WeThePeople', '#Hypocrisy', '#DoubleStandardDEMs', '#DeclassifyFISA', '#DeclassifyRelease302sUnredacted', '#DeclassifyPOWsDocuments', '#DarkToLIGHT']
# ['#Foolish', '#idiots', '#LetsGovern']
# ['#trump', '#maga']
# ['#SCOTUS']
# ['#dgps2018']
# ['#Zeyal', '#yasakelma']
# ['#TheResistance', '#ResistTrump', '#Antifa']
# ['#Trumpwashing']
# ['#BackTheBlue', '#gettough']
# ['#Antifa']
# ['#wilson', '#SonnyKiriakis', '#WillHorton', '#FreddieSmith', '#ChandlerMassey', '#Days', '#Days']
# ['#onlyatYAF']
# ['#maga']
# ['#MuellerWitchHunt', '#Manafort', '#Feinstein', '#DeepStateCorruption', '#DeepState', '#FBICorruption', '#MAGA', '#KAG', '#KAG2018', '#KAG2020', '#KeepAmericaGreat', '#ManafortTrial', '#CASen', '#Kavanaugh', '#ConfirmKavanaugh']
# ['#MAGA', '#2A', '#Prolife']
# ['#Kaepernick', '#JustDoIt']
# ['#MAGA']
# ['#seuday']
# ['#Winning', '#MAGA']
# ['#WWG1WGA', '#MAGA']
# ['#Science']
# ['#FakeNews', '#Liberals', '#DemocRats']
# ['#MAGA']
# ['#cnn']
# ['#JackDorseyIsAbigot', '#MAGA', '#KAG']
# ['#CartersBodysuitSweepstakes']
# ['#MichaelAvenatti']
# ['#healthyliving']
# ['#KavanaughForSCOTUS', '#2A', '#NRA', '#2A', '#DefendTheSecond', '#NRA', '#SHAREACT', '#NOCOMPROMISE', '#RememberYourOath', '#NRAun', '#2A', '#DefendTheSecond', '#NRA']
# ['#fakepsychologist']
# ['#WalkAway', '#idiot', '#MAGA']
# ['#RedNationRising', '#MAGA', '#WalkAway']
# ['#Distractification']
# ['#JustDoIt', '#UsOpen', '#Serena', '#MAGA']
# ['#maga']
# ['#MAGA', '#BuildTheWall', '#LockThemAllUp', '#FixIt']
# ['#MeToo', '#MAGA', '#WWG1WGA', '#ConfirmKavanaugh']
# ['#Putin', '#MAGA']
# ['#MAGA']
# ['#nhs', '#bbc', '#bbcqt', '#newsnight', '#bbcpl', '#channel4', '#Brexit', '#May', '#Corbyn', '#Labour', '#Conservatives', '#marr', '#hignfy', '#UKLabour', '#SkyNews', '#bbcLive', '#PoliticsLive']
# ['#LarryNassar']
# ['#TommyValhalla']
# ['#EXO']
# ['#MAGA', '#2A', '#Prolife']
# ['#FortTrump', '#Poland', '#BoomingEconomy']
# ['#Tories', '#Labour', '#GE2017', '#Conservatives']
# ['#Liberals']
# ['#paranoia', '#atomisation']
# ['#MAGA']
# ['#TripleTalaq']
# ['#MaunaLoa', '#CrunchToADifferentBeat', '#NFL', '#NCAA']
# ['#GOP', '#Republicans', '#Conservatives', '#Vote', '#Kavanaugh']
# ['#Antifa']
# ['#ConstitutionDay', '#Maga']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#ConfirmKavanaughNow', '#MAGA']
# ['#SaveTheRepublic', '#VoteThemOut', '#SaveDemocracy', '#Vote2018', '#MAGA', '#SmartDissent']
# ['#FakeDrugWar']
# ['#MAGA', '#KAG']
# ['#PanicInDC', '#QAnon', '#WWG1WGA']
# ['#jonesout']
# ['#VerifiedHate']
# ['#SuccessConnect']
# ['#Islamophobic', '#Islamophobia']
# ['#Cin', '#Days']
# ['#MAGA']
# ['#MAGA']
# ['#SexualMisconduct', '#Gay', '#GOP', '#Men', '#Mulligan', '#Hypocritical', '#Evangelicals']
# ['#resist', '#MAGA']
# ['#MAGA']
# ['#MAGA']
# ['#TheConstitutionIsTheSolution', '#WWG1WGA', '#MAGA', '#MEGA', '#FollowTheWhiteRabbit', '#Q', '#QAnon']
# ['#WeThePeople', '#GreatAwakening']
# ['#WWG1WGA', '#QAnon', '#QArmy', '#MAGA']
# ['#Trump', '#MAGA', '#KAG', '#TXSen', '#KeepTexasRed', '#RedWave']
# ['#MakeAmericaGreatAgain', '#AmericaFirst', '#MAGA', '#USA']
# ['#MayMustGo', '#StandUp4Brexit']
# ['#Privilege', '#MAGA']
# ['#Feinstein', '#China']
# ['#Fredo']
# ['#MAGA']
# ['#MAGA']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#realtornggiveaway']
# ['#FakeNews', '#MAGA']
# ['#NovemberIsComing']
# ['#NoDealBrexit', '#ChequersPlan', '#downfall', '#TheresaMay', '#brexiteer']
# ['#nowplaying']
# ['#MAGA']
# ['#MAGA', '#POTUS', '#MAGA', '#KAG']
# ['#MAGA']
# ['#MAGA']
# ['#FoxNews']
# ['#LeftistLibTards', '#Corrupt', '#Miserable']
# ['#MAGA']
# ['#Liberals']
# ['#BrettKavanaugh']
# ['#baltimore', '#guncontrol']
# ['#MAGA']
# ['#Antifa']
# ['#MAGA']
# ['#fesheyes']
# ['#TheresaMay', '#MonsterMay', '#Conservatives', '#DWPcrimes', '#DWP', '#Tories', '#ToriesOut']
# ['#MaxineWaters', '#RedWaveRising', '#GoodbyeDemocrats']
# ['#cleaningcanada', '#canadaelection2019', '#canada', '#Conservatives']
# ['#MAGA']
# ['#MSM', '#QANON', '#TrustThePlan', '#WWG1WGA', '#MAGA', '#KAG', '#KavanaughForSCOTUS']
# ['#valuinghealth2018']
# ['#HealthSucks']
# ['#SadNews', '#Republicans', '#Conservatives', '#Deplorables', '#Democrats', '#Liberals', '#Tolerables', '#WeThePeople', '#AmericanPeople']
# ['#JFKJr', '#kennedy', '#qanon', '#maga', '#magical']
# ['#Republicans']
# ['#conservatives', '#Maymustgo']
# ['#metoo']
# ['#MAGA']
# ['#4', '#0']
# ['#Remainers', '#Europe', '#democracy', '#totalitarian', '#beyrayal', '#inevitable', '#Brexit', '#EU', '#MBGA', '#MEGA', '#MAGA', '#MCGA', '#Conservatives', '#Patriots']
# ['#cocktribute', '#cumtribute']
# ['#Antifa']
# ['#maga']
# ...
# ['#MAGA']
# ['#MAGA']
# ['#ANTIFA']
# ['#StopKavanaugh']
# ['#status', '#heAndShe', '#newStatus', '#comingSoon', '#hplife']
# ['#TwitterPurge', '#TwitterCensorShip', '#Conservatives']
# ['#WalkAway', '#WWG1WGA', '#PizzaGate', '#QAnon', '#Hivites', '#MAGA', '#EagleOneToWanta']
# ['#MAGA']
# ['#HAPPYHYUNJAEDAY', '#BELIEVE_HYUNJAE_DAY', '#너의존재가_기적이야']
# ['#LEOs']
# ['#metoo']
# ['#MAGA']
# ['#THE_BOYZ', '#HYUNJAE', '#더보이즈', '#현재']
# ['#Tweet', '#community', '#MAGA', '#FargoLowes', '#Thanks', '#hurricaneFlorence', '#business', '#hurricaneseason', '#TuesdayThoughts', '#Technology', '#investments']
# ['#DevilYouLoseAgain', '#LetTheTribunalsBegin', '#TheRainmakers', '#TrumpWorld', '#Rainmakersunite', '#WWG1WGA', '#QAnon', '#MAGA', '#KAG', '#Q828', '#ThePersistence']
# ['#Antifa', '#OPMAYFLOWER', '#GoodTRUMPsEvil', '#PatriotsFight', '#QAnon', '#MAGA', '#MAGAbots', '#DigitalSoldiers', '#FISAGate', '#GITMO', '#Trump2020', '#DrainTheSwamp', '#EnjoyTheShow', '#LockHerUp', '#StrawberryRecall', '#WWG1WGA']
# ['#hypocrisy', '#TheStorm', '#maga', '#KAG', '#QAnon']
# ['#Dems']
# ['#cpc']
# ['#UK', '#fracking']
# ['#102']
# ['#MAGA']
# ['#MAGA', '#KAG', '#WalkAway', '#Witchhunt', '#RedWaveRising', '#VoteRed', '#VoteDemsOut', '#VoteRedToSaveAmerica']
# ['#MAGADingDong']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#MAGA', '#RedWaveRising']
# ['#Leftists', '#Commies', '#USA', '#MAGA', '#MBGA', '#MCGA', '#Socialists', '#Lefties', '#Conservatives', '#Patriots', '#MEGA', '#Trump', '#Democrats', '#Republicans']
# ['#DeepState', '#DeepStateCorruption', '#draintheswamp', '#kag']
# ['#fakenews', '#lyingnews']
# ['#kavanaugh', '#Resistance']
# ['#MOGG', '#JacobReesMogg', '#ChuckChequers', '#PrimeMinister', '#BBC', '#SKY', '#LBC', '#Tory', '#Tories']
# ['#Brexit']
# ['#RedWave']
# ['#MAGA', '#clearflynnNow']
# ['#TheView', '#maga']
# ['#FakeJournalists', '#FakeNews', '#NoHonor', '#MAGA']
# ['#MAGA', '#ReligiousFreedom', '#Republic', '#FreedomAndJusticeForALL']
# ['#America', '#MAGA', '#VoteRed']
# ['#MAGA']
# ['#EnemyOfThePeople']
# ['#MAGA']
# ['#VoteDemsOut', '#MAGA', '#2020', '#ConfirmJudgeKavanaugh']
# ['#DisarmHarrisNow']
# ['#MAGA', '#MAGA', '#VoteRED']
# ['#MAGA', '#KAG', '#TRUMP2020', '#TRUMP', '#TRUMP', '#WELUVTRUMP']
# ['#Ernie', '#Bert', '#ernieandbert', '#SesameStreet', '#Toad', '#MarioKart', '#TraitorTrump', '#traitortoad']
# ['#MAGA', '#BuildThatWall']
# ['#maga']
# ['#deepstate', '#deepstate', '#MAGA', '#rnc', '#gop', '#foxnews']
# ['#KavanaughConfirmationHearing', '#NEWS', '#Jobs', '#Job', '#marketing', '#music', '#art', '#fashion', '#ShopMyCloset', '#florence', '#ProjectManagement', '#Crypto', '#MAGA']
# ['#MAGA', '#ConfirmKavanaugh', '#DeepState']
# ['#LDConfBrexit']
# ['#MAGA']
# ['#Patriots', '#Maga']
# ['#brandmatters', '#guncontrol']
# ['#MAGA']
# ['#Emmy', '#Trump', '#Conservatives', '#MAGA', '#BoycottHollywood']
# ['#SaveAmericaFromDemocrats', '#VoteRedToSaveAmerica', '#KAG2018', '#MAGA']
# ['#boom', '#FISADeclassification', '#maga', '#QAnon', '#TrustSessions']
# ['#WALKAWAY', '#GORKEDDEMS', '#MAGA', '#WWG1WGA']
# ['#MAGA', '#MAGA']
# ['#Danish', '#Muslims', '#Welfare', '#Conservatives', '#UK', '#MBGA']
# ['#DemsWantTotalControl', '#LibsThinkTheyHaveAllTheAnswers', '#FreedomOfSpeechForAll']
# ['#ReleaseTheCures', '#DeclassifyFISA', '#ItsTime', '#LockThemAllUp', '#WWG1WGA', '#GreatAwakening', '#Winning', '#QAnon', '#MAGA', '#BitChute']
# ['#conservatives', '#God', '#BrettKavanuagh', '#Hypocrites']
# ['#StopKavanaugh', '#Sendhim', '#SmartNews']
# ['#winning', '#MAGA', '#QAnon']
# ['#maga']
# ['#MAGA', '#TDS', '#WalkAwayFromDemocrats2018']
# ['#Mississauga']
# ['#antifa', '#pussyhats', '#BLM']
# ['#NotBakingYourCake', '#ProudToLoveJesus']
# ['#MAGA']
# ['#MAGA']
# ['#FortTrump', '#Poland', '#BoomingEconomy']
# ['#HomeOffice', '#Terrorist', '#Choudary', '#MAGA', '#MEGA', '#MBGA', '#MBGA', '#Conservatives', '#Muslims', '#Migrants']
# ['#JOKE', '#patrickmouratoglou', '#Serena', '#race', '#gender', '#equality', '#cheating', '#ACCOUNTABILITY']
# ['#God']
# ['#MAGA']
# ['#EnemyOfThePeople']
# ['#whatajoke']
# ['#MAGA']
# ['#Potus', '#TRUMP', '#Maga']
# ['#ThursdayThoughts']
# ['#MAGA', '#TrumpTrain', '#KeepAmericaGreat2020']
# ['#Tories', '#Labour', '#GE2017', '#Conservatives']
# ['#VoteLabour', '#GE2018NOW', '#WeAreCorbyn', '#UnitedWeStand']
# ['#MAGA', '#PatriotsUnited', '#ProLife', '#ProIsrael', '#WeAreQ']
# ['#TheStruggleIsReal']
# ['#JesusITrustInYou']
# ['#DeepState', '#MAGA', '#LockThemUp']
# ['#walkaway']
# ['#maga']
# ['#GINSBERGISNEXT']
# ['#Antifa']
# ['#hollywoodisscum']
# ['#facts']
# ['#Rimmy4Antifa']
# ['#American', '#Flag', '#USA', '#USA_Flag_4U', '#Shop_8_9', '#MAGA', '#AmericaFirst', '#Trump', '#POL_8_27_QX']
# ['#FOXNEWS', '#CNN', '#THEVIEW', '#MAGA', '#ABCNEWS', '#CBSNEWS']
# ['#MAGA', '#WWG1WGA']
# ['#MAGA', '#RedWave']
# ['#HeyHey']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#MAGA', '#Trumps', '#Warrior', '#VoteRedToSaveAmerica']
# ['#MAGA']
# ['#MAGA', '#Patriot', '#Qanon', '#WalkAway', '#WWG1WGA', '#GodsArmy', '#TheGreatAwakening', '#JESUSLIVES', '#CatchTheRedWave', '#VoteRed', '#TrumpTrain']
# ['#NazisAreBad']
# ['#StopBrexit', '#PeoplesVote']
# ['#rePUNKlicans', '#ronaldgrump', '#naziUSA']
# ['#FrancisAglabtin2TulogNaLang']
# ['#Cruz']
# ['#Honorable', '#Judge', '#Kavanaugh']
# ['#Pray4TheUSA', '#Pray4Revival']
# ['#POTUS45', '#MAGA', '#Trump2020']
# ['#marketing', '#sales', '#retail', '#style']
# ['#VoteRed2018', '#NoVoterFraud', '#NoCaliforniaDemocrats', '#BuildTheWall', '#NoSanctuaryCities', '#NoSafeSpaces', '#NOHOMELESSCITIZEN', '#NoAmnesty', '#NoPelosi', '#NoWaters', '#NoHarris', '#nonewsom', '#NoSchiff', '#NoLieu', '#NoFeinstien', '#NoVoterFraud', '#Walkaway', '#PatriotsUnited', '#MAGA', '#PardonMyFrench']
# ['#Ridiculous']
# ['#AntiFA', '#TooSoon']
# ['#GOAT']
# ['#Hypocrite']
# ['#MAGA']
# ['#80s', '#BREAKING', '#FORTNITEANDROID', '#kungfu', '#fantasy', '#movies', '#Trump', '#maga', '#80s', '#tech', '#texas', '#trending', '#SundayMotivation', '#maga', '#gop', '#GameofThrones', '#beard', '#men', '#news', '#BREAKING', '#kungfu', '#shop', '#shoponline', '#TXSen', '#texas']
# ['#latinosfortrump']
# ['#DogWhistle']
# ['#Islamism', '#Left', '#Marxists', '#Progressives', '#Socialists', '#BrownShirts', '#ANTIFA', '#constitutional', '#USARepublic']
# ['#Enebot']
# ['#politicslive', '#neveragain']
# ['#FACEBOOK', '#LEFT', '#LIBERAL', '#DemocraticParty', '#MAGA', '#Midterms2018', '#NRA', '#2A', '#1AB', '#ConfirmJudgeKavanaugh', '#ConfirmKavanaugh', '#ConstitutionDay', '#USMC', '#NAVY', '#ARMY', '#AirForce', '#Conservative']
# ['#class', '#coolaintforsale']
# ['#crookedtrump', '#countrybeforeparty']
# ['#long', '#cox']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#MAGA']
# ['#WWG1WGA', '#MAGA']
# ['#Conservatives', '#Housing', '#TheresaMay', '#HousingForAll', '#HousingCrisis', '#HousingMarket', '#NHF18']
# ['#NewYork', '#State', '#Republicans', '#Conservatives', '#Democrats', '#VOTE', '#Governor']
# ['#NeverAgain']
# ['#MAGA']
# ['#ChristineBlaseyFord', '#MAGA']
# ['#MAGA']
# ['#TheDreamAct', '#BuildThatWall', '#EndDaca']
# ['#conservatives', '#republican', '#MAGA', '#Shadowbanning', '#AmericaFirst', '#Trump', '#Patriot', '#WalkAway', '#WalkAwayFromDemocrats', '#FakeNews']
# ['#MAGA']
# ['#Liberal']
# ['#MuellerIsComingForYouToo', '#PatheticLittleManJr']
# ['#MAGA']
# ['#Westminster', '#Tories', '#Brexit', '#MurderRate', '#London']
# ['#MAGA']
# ['#RightSideOfHistory', '#BigTech']
# ['#Europe']
# ['#NoToKavanaugh']
# ['#MAGA', '#Trump2020']
# ['#TrumpTrain']
# ['#Trump']
# ['#Yemen', '#theeconomist']
# ['#KAG2018']
# ['#DarkToLight', '#Qanon', '#GreatAwakening', '#WWG1WGA', '#IBOR', '#MAGA', '#MBGA', '#WTOBREXIT']
# ['#oldageproblems', '#MAGA']
# ['#LetSomebodyLoveYou', '#Life']
# ['#cdnpoli']
# ['#Notwithkap', '#BoycottNike', '#MAGA']
# ['#criminals']
# ['#fatbastard']
# ['#Kavanaugh', '#MAGA', '#MakeAmericaGreatAgain']
# ['#MAGA']
# ['#maga']
# ['#metoo']
# ['#MAGA', '#VoteRepublican2018', '#VoteRed2018', '#AmericaFirst', '#KeepAmericaGreat']
# ['#FISA', '#GreatAwakening', '#DrainTheSwamp', '#MAGA', '#QAnon']
# ['#MAGA']
# ['#luddites', '#gigeconomy', '#ThursdayThoughts']
# ['#Westminster', '#Tories', '#Brexit', '#Brexiteers', '#UK', '#OutOfTheEU', '#Hungary', '#tyrannical', '#EU', '#dictatorship', '#ThirdReich']
# ['#MAGA']
# ['#MAGA']
# ['#Qanon', '#WWG1WGA', '#MAGA']
# ['#MAGA']
# ['#BrettKavanaugh']
# ['#EricHolderCrimes']
# ['#DrainTheDeepState', '#MAGA']
# ['#SimonSays']
# ['#EnoughIsEnough']
# ['#MAGA', '#KAG']
# ['#EXPOSETHEDEEPSTATE', '#enemiesofthestate', '#militarytribunals', '#MAGA', '#TRUMP', '#WalkAway', '#Q']
# ['#ThursdayThoughts']
# ['#Quebec2018']
# ['#TheGreatAwakening', '#MAGA', '#QAnon']
# ['#MAGA']
# ['#1', '#2', '#3', '#4', '#5']
# ['#MAGA']
# ['#ProLife', '#Maga']
# ['#SocialJustice', '#Fascist', '#identityPolitics']
# ['#Montel']
# ['#ThursdayThoughts']
# ['#evangelist']
# ['#DidYouKnow', '#Texas', '#HelenKeller', '#DoYouKnow', '#TXBOE', '#TXEd', '#Education', '#TheMoreYouKnow', '#TuesdayThoughts']
# ['#Resistance']
# ['#ConfirmKavanaugh']
# ['#flog']
# ['#drellenbrandt', '#MAGA']
# ['#antifa']
# ['#WWG1WGA', '#MAGA']
# ['#antifa']
# ['#Doit']
# ['#MAGA']
# ['#MAGA', '#ConfirmKavanaugh', '#PJNET']
# ['#reunite', '#immigrant', '#children', '#repeal', '#ban', '#FamiliesBelongTogether', '#NoBan']
# ['#MAGA']
# ['#keepitup', '#LiberalismIsAMentalDisease']
# ['#Fisa']
# ['#antifa']
# ['#xrpcommunity', '#xrp']
# ['#MeToo', '#VoteRedToSaveAmerica', '#MAGA']
# ['#MAGA']
# ['#RememberingEdward']
# ['#ClintonCrimeFamily']
# ['#Occupy', '#Ferguson', '#BaltimoreRiots', '#Resist', '#Antifa']
# ['#MAGA']
# ['#MAGA']
# ['#MaxineWaters', '#Trump', '#MAGA']
# ['#youhadonejob']
# ['#Republicans', '#Conservatives']
# ['#WalkAway', '#MAGA', '#DoTheRightThing', '#ConfirmKavanaugh']
# ['#DEPLORABLES', '#MAGA', '#KAG']
# ['#publicsector', '#digital']
# ['#MAGA']
# ['#wcw', '#pixiegang']
# ['#antifa']
# ['#MAGA']
# ['#ILLEGALALIEN', '#405', '#Kavanaugh', '#MAGA']
# ['#Election2018', '#GOP', '#RedWave', '#Trump', '#MAGA']
# ['#MeToo']
# ['#Conservatives']
# ['#GunControlNow']
# ['#MAGA']
# ['#democrats', '#liberals', '#walkaway', '#Hypocrites']
# ['#DownwiththeDemocrats', '#DemocratsHateAmerica', '#DemocratsAreDangerous', '#VoteDemsOut', '#VoteRedToSaveAmerica', '#Conservatives', '#WalkAway', '#LiberalismIsAMentalDisorder', '#VoteRed2018']
# ['#ChequersPlan']
# ['#Texas', '#resist', '#MAGA', '#Ridiculous']
# ['#WW', '#MondayMood', '#MAGA', '#DeclassifyItAll']
# ['#MAGA']
# ['#LeftWingLiberalDisease', '#WalkAway', '#VoteRedToSaveAmerica', '#MAGA']
# ['#TheFeralLeft', '#Liberals', '#Infiltrate', '#Indoctrinate', '#Hemorrhoids']
# ['#Kavanaugh', '#KavanaughHearings']
# ['#WWG1WGA', '#MAGA']
# ['#MAGA', '#NoKoSoKo']
# ['#MAGA', '#AmericaFirst']
# ['#Shrewd']
# ['#SocialismSucks']
# ['#Resist']
# ['#MAGA', '#ArrestClintonCrimeGangAlready', '#NoChainMigration', '#Trump2020', '#Spygate']
# ['#workout']
# ['#FordNation']
# ['#MAGA', '#PJNET', '#KAG', '#TrumpTrain', '#TrumpTrain2020']
# ['#MAGA']
# ['#Tennessee', '#Conservatives', '#RNRTN', '#2ADefenders', '#Republicans', '#ProLifeGen', '#TNGOP', '#Libertarians', '#ProLife', '#Gaytriots', '#RNR', '#CCOT']
# ['#TheresaMay', '#PeoplesVote']
# ['#EverybodyIn']
# ['#Hollywood', '#liberals']
# ['#Grenfell']
# ['#Politics', '#Government']
# ['#RiceKing', '#usefulidiot', '#QAnon', '#MAGA']
# ['#TripleTalaq']
# ['#MAGA', '#TCOT', '#KAG']
# ['#Conservatives', '#BrexitShambles']
# ['#MAGA']
# ['#Maga']
# ['#kavanaugh', '#allegations', '#ConfirmJudgeKavanaughNow', '#MAGA']
# ['#Brexit']
# ['#ReleaseTheCures', '#DeclassifyFISA', '#ItsTime', '#LockThemAllUp', '#WWG1WGA', '#GreatAwakening', '#Winning', '#QAnon', '#MAGA']
# ['#Man']
# ['#fascisme', '#Antifa', '#AntiFascist']
# ['#MAGA']
# ['#SecondAmendment']
# ['#DemocraticSocialismNow', '#NoMoreGuns']
# ['#BrettKavanaugh', '#ChristineBlaseyFord', '#StopKanavaugh', '#LiesUnderOath', '#SaveSCOTUS', '#CorruptGOP', '#maga', '#NoManIsAboveTheLaw', '#TrumpIsGuilty', '#VoteBlue', '#VoteBlue2018']
# ['#Brexit']
# ['#MAGA2020', '#WeThePeople', '#MAGA', '#Qanon8chan']
# ['#QAnon', '#Qanuck', '#AskTheQ', '#WeThePeople', '#TheGreatAwakening', '#TheStorm', '#MAGA', '#WWG1WGA']
# ['#LockThemAllUp', '#HandCuffsForHillary', '#MAGA']
# ['#politicslive', '#Conservatives', '#Tories', '#Labour']
# ['#WakeUpAmerica', '#AmericaFirst', '#MAGA', '#Trump2020', '#KAG2020', '#RedWaveRising2018', '#VoteRed2018', '#TXSen', '#VoteRedToSaveAmerica', '#KeepTexasRed', '#TedCruz2018', '#BuildTheWall', '#VoterID', '#ConfirmKavanaugh', '#WalkAwayCampaign', '#WalkAway', '#LiberalHate', '#LiberalIntolerance', '#SocialistLies', '#VetoBeto']
# ['#maga', '#KeepAmericaGreat']
# ['#Liberals', '#MeToo', '#ConfirmJudgeKavanaughNow', '#SenatorFeinstein', '#DemocratsHateAmerica']
# ['#COS']
# ['#QAnon']
# ['#conservatives', '#Kansas']
# ['#Antifa', '#Democrat']
# ['#FakeNews', '#MAGA']
# ['#ConfirmKavanaugh', '#MAGA', '#DrainTheDeepState']
# ['#MAGA', '#QAnon', '#TRDJ', '#WWG1WGA']
# ['#lakergang']
# ['#EqualJustice', '#Dems']
# ['#MAGA', '#LockThemAllUp', '#confirmkavanaugh', '#WWG1WGA', '#PatriotsUnited', '#GodBlessAmerica', '#GodBlessTheWorld', '#GodBlessOurMilitary', '#100thMonkey']
# ['#MAGA']
# ['#MAGA']
# ['#MAGA', '#DrainTheDeepState', '#ConfirmKavanaugh', '#TraitorsAll']
# ['#Antifa']
# ['#guncontrol', '#robbery', '#murder', '#Selfdense', '#Defend', '#secondammendment']
# ['#WalkAway', '#MAGA', '#WWG1WGA']
# ['#brexit', '#remain']
# ['#MAGA', '#ReleaseTheDocuments']
# ['#Trudeau', '#Liberals']
# ['#KKK', '#KKK', '#2A', '#Gunsense', '#WhateverItTakes']
# ['#MaximeBernier']
# ['#DonaldTrump', '#maga', '#metoo']
# ['#MoronsAreGoverningAmerica', '#MAGA', '#Kavanaugh']
# ['#investigateChtistineFord']
# ['#MAGA', '#WalkAway']
# ['#FoxNews']
# ['#Liberals', '#Democrats', '#ImLovingIt', '#MAGA', '#WalkAway']
# ['#DontMessAroundWith']
# ['#justdoit', '#nike']
# ['#WashingtonPost', '#VoteDemsOut', '#DirtyTricks', '#DC', '#Kavanaugh', '#maga', '#FoxNews', '#Liar', '#CNN', '#msnbc', '#SenFlake', '#Wrong', '#MeToo', '#ChristineBlaseyFord']
# ['#maga', '#WalkAway']
# ['#MalcolmX']
# ['#VoteRedToSaveAmerica']
# ['#MAGA']
# ['#usaafr18']
# ['#QANON', '#MAGA', '#GREATAWAKENING']
# ['#IDoNotConsent', '#WeDoNotConsent', '#OpEvidence', '#opstopchemtrails', '#Chemtrails', '#SkyBastard', '#Geoengineering', '#climatechange', '#SRM', '#Cloudseeding', '#EverGreenAir', '#BigMoney', '#NEXRAD', '#LookUp', '#SilentWarfare', '#WeatherWarfare', '#MAGA', '#potus', '#breakingnews']
# ['#TourismJobs', '#GOP', '#maga', '#uspoli', '#USPolitics']
# ['#BoycottTheNFL', '#TakeAStand']
# ['#MAGA']
# ['#MaximeBernier', '#liberalValues', '#DonPittis']
# ['#MAGA']
# ['#CartersBodysuitSweepstakes']
# ['#QAnon', '#MAGA']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#2A']
# ['#BING', '#NeverVoteDemocRAT', '#MAGA2018']
# ['#MAGA']
# ['#KavanaughConfirmation', '#TuesdayThoughts', '#MAGA']
# ['#Resist', '#Liberals', '#FakeNews', '#Democrats', '#PP', '#Antifa', '#WomensMarch', '#MaxineWaters', '#Kavanaugh', '#HillaryClinton', '#MAGA', '#Maddow', '#VoteRed2018']
# ['#cdnpoli', '#cdnhist']
# ['#Tories', '#Labour', '#GE2017', '#Conservatives']
# ['#SaveOurNHS']
# ['#TheLiberalWay', '#DEMS', '#MAGA']
# ['#MAGA']
# ['#KeepTexasRed']
# ['#MAGA']
# ['#NoOneCares']
# ['#censorship', '#ConfirmKavanaugh', '#ConfirmKavenaugh', '#maga']
# ['#Bullshit']
# ['#Kavanaugh']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#GINSBERGISNEXT']
# ['#Antifa', '#WA', '#POLICE', '#Police', '#Combat', '#ThinBlueLine', '#MAGA', '#KAG', '#BlueLivesMatter', '#LawEnforcement', '#2A']
# ['#guns', '#2A']
# ['#stopthebias', '#Conservative', '#Republican', '#Trump', '#Freespeech', '#twitter', '#liberals']
# ['#Brexit']
# ['#skynews', '#skypapers', '#bbcdp', '#lbc', '#lbclive', '#talkradio', '#altnews', '#brexit', '#remain', '#london', '#cityoflondon', '#news', '#breakingnews', '#uknews', '#labour', '#tories', '#trump', '#toryparty', '#ukip', '#conservatives', '#christians', '#qanon']
# ['#MAGA', '#MAGAts']
# ['#TCOT', '#MAGA', '#RedNationRising']
# ['#MAGA', '#BestPres45']
# ['#teamspotlightsunday']
# ['#Patriots', '#maga', '#WWG1WGA']
# ['#MAGA']
# ['#MAGA']
# ['#KeithEllisonAbuse']
# ['#FNMA', '#FMCC', '#fanniegate', '#EndCorruption', '#LockThemAllUp', '#MAGA']
# ['#Googlearecorrupt', '#BestuseQwant']
# ['#MondayMotivation', '#MAGA', '#MAAA']
# ['#irony']
# ['#MohammadHassanKhalid', '#traitor', '#USA', '#Islamists']
# ['#Antifa']
# ['#MAGA']
# ['#MAGA']
# ['#CommanderInChief', '#MakeAmericaGreatAgain', '#AmericaFirst', '#MAGA', '#USA']
# ['#Fact', '#TuesdayThoughts']
# ['#JenShad', '#AdiYa', '#Bepannaah']
# ['#Spanishrevenge', '#justice', '#HumanRights', '#FreedomOfExpression', '#Spain', '#fakedemocracy', '#cddr', '#shameonSpain', '#WakeupEurope']

# %%
print("Count number of tweets with hashtags: {} ({}%)".format(len(all_id_hashtags), round(100*len(all_id_hashtags)/len(train), 2)))

occ_hashtags = Counter(all_hashtags)
print(occ_hashtags.most_common())
# Out:
# Count number of tweets with hashtags: 1925 (14.54%)
# [('#MAGA', 737), ('#maga', 75), ('#Conservatives', 72), ('#WWG1WGA', 72), ('#KAG', 67), ('#WalkAway', 64), ('#QAnon', 55), ('#Kavanaugh', 50), ('#Antifa', 48), ('#TCOT', 41), ('#RedNationRising', 40), ('#Liberals', 39), ('#Trump', 36), ('#2A', 32), ('#ConfirmKavanaugh', 30), ('#antifa', 25), ('#Tories', 25), ('#conservatives', 23), ('#cdnpoli', 21), ('#Trump2020', 20), ('#Labour', 19), ('#Brexit', 18), ('#Democrats', 18), ('#USA', 17), ('#DrainTheSwamp', 17), ('#VoteRedToSaveAmerica', 17), ('#FakeNews', 17), ('#MeToo', 16), ('#MEGA', 16), ('#MBGA', 16), ('#Patriots', 16), ('#AmericaFirst', 16), ('#TrumpTrain', 16), ('#tcot', 15), ('#Republicans', 15), ('#metoo', 14), ('#Maga', 13), ('#DrainTheDeepState', 13), ('#WeThePeople', 13), ('#GE2017', 13), ('#MCGA', 12), ('#TheGreatAwakening', 12), ('#GreatAwakening', 12), ('#TuesdayThoughts', 12), ('#NRA', 12), ('#liberals', 12), ('#MakeAmericaGreatAgain', 12), ('#TRUMP', 11), ('#qanon', 11), ('#VoteRed2018', 11), ('#Qanon', 11), ('#walkaway', 11), ('#ThursdayThoughts', 10), ('#KAG2018', 10), ('#DeepState', 10), ('#trump', 10), ('#Resist', 10), ('#ChristineBlaseyFord', 9), ('#ANTIFA', 9), ('#VoteDemsOut', 9), ('#LockThemAllUp', 9), ('#POTUS', 9), ('#RedWaveRising', 9), ('#VoteRed', 9), ('#PeoplesVote', 9), ('#FortTrump', 9), ('#WednesdayWisdom', 9), ('#GOP', 9), ('#ConstitutionDay', 9), ('#brexit', 9), ('#Muslims', 8), ('#PJNET', 8), ('#guncontrol', 7), ('#KavanaughConfirmation', 7), ('#Q', 7), ('#QANON', 7), ('#RedWave', 7), ('#ConfirmKavanaughNow', 7), ('#CCOT', 7), ('#resist', 7), ('#MondayMotivation', 7), ('#Prolife', 7), ('#Poland', 7), ('#BoomingEconomy', 7), ('#WalkAwayFromDemocrats', 7), ('#TheResistance', 7), ('#Westminster', 7), ('#MSM', 7), ('#QArmy', 7), ('#BuildTheWall', 7), ('#TheresaMay', 7), ('#StopKavanaugh', 6), ('#UK', 6), ('#Police', 6), ('#remain', 6), ('#TRUMP2020', 6), ('#America', 6), ('#LockHerUp', 6), ('#GunControl', 6), ('#Winning', 6), ('#FoxNews', 6), ('#guns', 6), ('#KeepAmericaGreat', 6), ('#ConfirmJudgeKavanaugh', 6), ('#WakeUpAmerica', 5), ('#Leftists', 5), ('#LeviStrauss', 5), ('#Resistance', 5), ('#MAGA2020', 5), ('#WINNING', 5), ('#BoycottNike', 5), ('#Emmys', 5), ('#Democrat', 5), ('#LiberalismIsAMentalDisorder', 5), ('#NEWS', 5), ('#EU', 5), ('#Mueller', 5), ('#KAG2020', 5), ('#MAGA2KAG', 5), ('#news', 5), ('#1', 5), ('#AskAlly', 5), ('#StopBrexit', 5), ('#PatriotsUnited', 5), ('#Deplorables', 5), ('#CNN', 5), ('#DeepStateCorruption', 4), ('#politicslive', 4), ('#BrettKavanaugh', 4), ('#Hollywood', 4), ('#onpoli', 4), ('#BoycottNFL', 4), ('#deepstate', 4), ('#Canada', 4), ('#gunsense', 4), ('#LiberalismIsAMentalDisease', 4), ('#VoteBlue', 4), ('#qanda', 4), ('#Florida', 4), ('#politics', 4), ('#pnpcbc', 4), ('#breakingnews', 4), ('#KeepTexasRed', 4), ('#RedWave2018', 4), ('#KavanaughConfirmationHearings', 4), ('#EnoughIsEnough', 4), ('#GunControlNow', 4), ('#Congress', 4), ('#wwg1wga', 4), ('#California', 4), ('#LBC', 4), ('#NFL', 4), ('#BREAKING', 4), ('#TrumpsArmy', 4), ('#labour', 4), ('#FreedomOfExpression', 4), ('#kag', 4), ('#TheStorm', 4), ('#Dems', 4), ('#DemocratsHateAmerica', 4), ('#war', 4), ('#BLM', 4), ('#WalkAwayDemocrats2018', 3), ('#racism', 3), ('#Soros', 3), ('#democrats', 3), ('#Obama', 3), ('#Liberal', 3), ('#gop', 3), ('#ccot', 3), ('#Islam', 3), ('#brexitshambles', 3), ('#TheRainMakers', 3), ('#Conservative', 3), ('#fakenews', 3), ('#Remainers', 3), ('#HardBrexit', 3), ('#SCOTUS', 3), ('#Europe', 3), ('#DianeFeinstein', 3), ('#ClarenceThomas', 3), ('#POTUS45', 3), ('#RSSReachesOut', 3), ('#Rimmy4Antifa', 3), ('#Trudeau', 3), ('#ONpoli', 3), ('#SaveSCOTUS', 3), ('#RedWaveRising2018', 3), ('#Walkaway', 3), ('#MolonLabe', 3), ('#ethics', 3), ('#VoteThemOut', 3), ('#GodBlessAmerica', 3), ('#ToriesOut', 3), ('#Brexiteers', 3), ('#OutOfTheEU', 3), ('#BlackLivesMatter', 3), ('#MorningJoe', 3), ('#LawEnforcement', 3), ('#DNC', 3), ('#AntiFA', 3), ('#liberal', 3), ('#PPC', 3), ('#cpc', 3), ('#lpc', 3), ('#HumanRights', 3), ('#LionsDen ...

# %%
pd.DataFrame.from_dict(occ_hashtags, orient='index')
# Out:
#                           0
# #MAGA                   737
# #Trump2020               20
# #Amazon                   1
# #KAG                     67
# #CHINA                    1
# #TCOT                    41
# #LooneyLeft               1
# #Liberals                39
# #Qproofs                  1
# #TrudeauMustGo            2
# #Kavanaugh               50
# #confirmed                1
# #DemsareFrauds            1
# #DemsAreDone              1
# #WalkAwayDemocrats2018    3
# #redwave                  2
# #VoteRedSaveAmerica       1
# #trumptrain               2
# #DeepStateCorruption      4
# #guncontrol               7
# #cdnpoli                 21
# #cdnhist                  2
# #PutUpOrShutUp            1
# #CallTheVoteAlready       1
# #RedNationRising         40
# #President                1
# #Trump                   36
# #DEMSUCK                  1
# #racism                   3
# #Windrush                 2
# ...                     ...
# #PP                       1
# #WomensMarch              1
# #HillaryClinton           1
# #SaveOurNHS               1
# #TheLiberalWay            1
# #NoOneCares               1
# #censorship               1
# #ConfirmKavenaugh         1
# #Bullshit                 1
# #stopthebias              1
# #Freespeech               1
# #twitter                  1
# #BestPres45               1
# #KeithEllisonAbuse        1
# #FNMA                     1
# #FMCC                     1
# #fanniegate               1
# #EndCorruption            1
# #Googlearecorrupt         1
# #BestuseQwant             1
# #MAAA                     1
# #irony                    1
# #MohammadHassanKhalid     1
# #Islamists                1
# #CommanderInChief         1
# #JenShad                  1
# #AdiYa                    1
# #Bepannaah                1
# #Spanishrevenge           1
# #WakeupEurope             1
#
# [2385 rows x 1 columns]

# %%
sns.boxplot(x=pd.DataFrame.from_dict(occ_hashtags, orient='index'))

# %%
def extract_hashtags(x):
    hashtags = []
    for i in x:
        ht = re.findall(r"#(\w+)",i)
        hashtags.append(ht)
        
    return hashtags

# %%
hashtags_off = extract_hashtags(train["tweet"][train['subtask_a']=="OFF"])
hashtags_not = extract_hashtags(train["tweet"][train['subtask_a']=="NOT"])

# %%
hashtags_off = sum(hashtags_off,[])
hashtags_not = sum(hashtags_not,[])

# %%
hashtags_off = [hashtag.lower() for hashtag in hashtags_off]
hashtags_not = [hashtag.lower() for hashtag in hashtags_not]

# %%
occ_hashtags_off = Counter(hashtags_off)
occ_hashtags_not = Counter(hashtags_not)

# %%
pd.DataFrame.from_dict(occ_hashtags_off, orient='index')
# Out:
#                              0
# maga                       242
# trump2020                    6
# looneyleft                   1
# liberals                    22
# qproofs                      1
# trudeaumustgo                1
# deepstatecorruption          1
# putuporshutup                1
# kavanaugh                   21
# callthevotealready           1
# president                    1
# trump                       15
# demsuck                      1
# kavanaughconfirmation        2
# woke                         1
# qanon                       20
# wakeupamerica                4
# levistrauss                  1
# dems                         1
# obama                        2
# crookedhillary               2
# christineblaseyford          2
# confirmkavanaugh            13
# weakrinos                    1
# republicans                  9
# liberal                      1
# dem                          2
# firemorningjoe               1
# christineford                1
# tcot                        11
# ...                        ...
# confirmjudgekavanaughnow     1
# senatorfeinstein             1
# kansas                       1
# lakergang                    1
# godblessamerica              1
# godblesstheworld             1
# godblessourmilitary          1
# 100thmonkey                  1
# traitorsall                  1
# kkk                          2
# whateverittakes              1
# moronsaregoverningamerica    1
# imlovingit                   1
# washingtonpost               1
# dirtytricks                  1
# dc                           1
# msnbc                        1
# senflake                     1
# wrong                        1
# cdnhist                      1
# censorship                   1
# confirmkavenaugh             1
# bullshit                     1
# bestpres45                   1
# keithellisonabuse            1
# fnma                         1
# fmcc                         1
# endcorruption                1
# googlearecorrupt             1
# bestuseqwant                 1
#
# [739 rows x 1 columns]

# %%
df_occ_hashtags_not = pd.DataFrame.from_dict(occ_hashtags_not, orient='index')

# %%
df_occ_hashtags_not[df_occ_hashtags_not[0]>1]
# Out:
#                          0
# maga                   583
# kag                     60
# china                    3
# tcot                    46
# kavanaugh               32
# walkawaydemocrats2018    2
# redwave                  6
# trumptrain              16
# guncontrol              11
# cdnpoli                 16
# rednationrising         34
# racism                   3
# windrush                 2
# politicslive             6
# metoo                   22
# stopkavanaugh            5
# americafirst            13
# usa                     14
# leadership               2
# economy                  2
# jobs                     2
# trump                   42
# soros                    2
# walkaway                53
# antifa                  72
# mega                    11
# mbga                     9
# mcga                     8
# conservatives           77
# patriots                10
# ...                    ...
# europe                   2
# wcw                      2
# teamspotlightsunday      2
# progressives             3
# levi                     2
# confirmjudgekavanaugh    3
# 2                        2
# christians               3
# pussyhats                2
# fisa                     3
# skypapers                2
# bbcdp                    2
# lbclive                  2
# talkradio                2
# altnews                  2
# cityoflondon             2
# uknews                   2
# toryparty                2
# housingcrisis            2
# war                      4
# maximebernier            3
# wednesdaymotivation      2
# amazonpets               2
# 2adefenders              2
# buildthatwall            2
# ginsbergisnext           2
# novoterfraud             2
# 80s                      2
# kungfu                   2
# texas                    3
#
# [411 rows x 1 columns]

# %%
df_occ_hashtags_off = pd.DataFrame.from_dict(occ_hashtags_off, orient='index')

# %%
df_occ_hashtags_off[df_occ_hashtags_off[0]>10]

# %%
sns.boxplot(x=df_occ_hashtags_off)

# %%
sns.boxplot(x=pd.DataFrame.from_dict(occ_hashtags_not, orient='index'))

# %%
def plot_hashtags(hashtags):
    freq = nltk.FreqDist(hashtags)
    df = pd.DataFrame({'Hashtag': list(freq.keys()),
                      'Count': list(freq.values())})
    df = df.nlargest(columns="Count", n = 10) 
    plt.figure(figsize=(16,5))
    ax = sns.barplot(data=df, x= "Hashtag", y = "Count")
    ax.set(ylabel = 'Count')
    plt.show()

# %%
plot_hashtags(hashtags_off)

# %%
plot_hashtags(hashtags_not)

# %% [markdown]
# ### Spelling correction

# %%
#https://pypi.org/project/pyspellchecker/
#https://github.com/phatpiglet/autocorrect
spell = SpellChecker()

misspelled = spell.unknown(['something', 'is', 'hapenning', 'here'])

for tweet in train['tweet'][1:10]:
    ex = clean(tweet)
    print(ex)
    ex = ex.split(" ")
    misspelled = spell.unknown(ex)
    print(misspelled)
    for word in misspelled:
        try:
            correction = spell.correction(word)
            print(correction)
        except:
            print("None")
            
#Probably don't use spellingcoorrection
#Corrections are not really good..

# %% [markdown]
# ### Contractions

# %%
ex = train['tweet'][3]
print(ex)

new = contractions.fix(ex, slang=True)
print(new)

# %% [markdown]
# ### Class Imbalance

# %%
print("Total comments:", len(train))

missing_values = train.isnull().sum(); missing_values

print("Fill NA with unknown")
train = train.fillna("UNKOWN")
train.head(10)

def distribution(test, subtask, order):
    """
    Arguments:
        test: Test set A, B, C
        subtask: Subtask name (subtask_a, subtask_b, subtask_c)
        order: Order of the categories in the subtask (list)

    Output:
        Value percentages, count for the train and test set
        Countplots for the train and test set
    """
    print("Train: \n")
    print(train[subtask].value_counts(normalize=True))
    print(train[subtask].value_counts(normalize=False))

    print("Test: \n")
    print(test[subtask].value_counts(normalize=True))
    print(test[subtask].value_counts(normalize=False))

    sns.countplot(x=subtask, data=train, order=order)
    plt.title("Train")
    plt.show()

    sns.countplot(x=subtask, data=test, order=order)
    plt.title("Test")
    plt.show()

### Subtask A ####
distribution(test_a, 'subtask_a', ['OFF', 'NOT'])

# The are a lot more not offensive train than offensive train. The percentage is around 67% vs 33%.

### Subtask B ###
distribution(test_b, 'subtask_b', ['UNT','TIN'])
#UNT: Untargeted - A post containing non-targeted profanity and swearing
#TIN: Target Insult and Threats - A post containing an insult or threat to an individual, a group, or others

# The target group is large (88%) vs (12%) untargeted group.

### Subtask C ###
distribution(test_c, 'subtask_c', ['OTH','GRP','IND'])

#Ind. group is large

# The individual group is large in comparison to the other groups. There offensive train are more targeted to individuals.

### Subtasks ###
print(train.groupby(['subtask_a','subtask_b','subtask_c']).size())
train.head(1)
subtasks = pd.melt(train, id_vars=["id","tweet"], value_vars=['subtask_a','subtask_b','subtask_c'])
subtasks.head(5)

subtasks_normalize = subtasks.groupby(['variable'])['value'].value_counts(normalize=True).rename('percentage').reset_index()
subtasks_normalize

(ggplot() + geom_bar(aes(y= 'percentage' ,x = 'variable', fill = 'value'), data=subtasks_normalize, stat="identity"))
sns.barplot(x='variable', y='percentage', hue='value', data=subtasks_normalize)

# %% [markdown]
# ### Wordclouds

# %%
### Wordclouds ###
def generate_wordcloud(text):
    # Create stopwords
    stopwords = set(STOPWORDS)
    stopwords.add("USER")
    stopwords.add("URL")
    stopwords.add("amp")

    # Generate word cloud image
    wordcloud = WordCloud(stopwords=stopwords, max_words=300, background_color="black").generate(text)

    # Show image
    plt.figure(figsize=(20,10))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()

text = " ".join(tweet for tweet in train["tweet"])
not_text = " ".join(tweet for tweet in train.loc[train["subtask_a"]=="NOT","tweet"])
off_text = " ".join(tweet for tweet in train.loc[train["subtask_a"]=="OFF","tweet"])
off_tin_unt_text = " ".join(tweet for tweet in train.loc[train["subtask_b"]=="UNT","tweet"])
off_tin_ind_text = " ".join(tweet for tweet in train.loc[train["subtask_c"]=="IND","tweet"])
off_tin_grp_text = " ".join(tweet for tweet in train.loc[train["subtask_c"]=="GRP","tweet"])
off_tin_oth = " ".join(tweet for tweet in train.loc[train["subtask_c"]=="OTH","tweet"])

generate_wordcloud(text)
generate_wordcloud(not_text)
generate_wordcloud(off_text)
generate_wordcloud(off_tin_unt_text)
generate_wordcloud(off_tin_ind_text)
generate_wordcloud(off_tin_grp_text)
generate_wordcloud(off_tin_oth)

# %% [markdown]
# ## Cleaning

# %%
from data_loader import encode_label, clean_text, load_data, clean_data
import pandas as pd
from pytorch_pretrained_bert.tokenization import BertTokenizer

subtask="a"

train, val, test = load_data(subtask)

total = pd.concat([train, val, test])
labels = encode_label(total["label"])
text_clean = [clean_text(text, False,False, False) for text in total["text"]]

bert_data = pd.DataFrame({"text_origineel":total["text"], "text":text_clean, "label":labels})
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)

# %%
total_len = []
for index, example in bert_data.iterrows():

    tokens_text = tokenizer.tokenize(example.text)
    total_len = total_len.append(len(tokens_text))
